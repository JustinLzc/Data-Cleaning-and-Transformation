# %% [markdown]
# # Data Cleaning and Transformation of Web-Scraped Indeed Job Listings

# %% [markdown]
# ### Data Description
# A web-scraped data of job postings for Data Science roles from Indeed. Here's a breakdown of the columns:
#
# * Title: A brief description or responsibility of the job.
# * Title_URL: The URL of the job posting on Indeed's website.
# * Title1: Job title.
# * Company_name: The name of the company offering the job.
# * Location: The location where the job is based.
# * attribute_snippet: Salary information, formatted as a range.
# * metadata__divcontains_class_attribute_snippet: Job Type.
# * jobsnippet: Additional information about the job responsibilities or requirements.
# * jobsnippet2: Additional information about the job responsibilities or requirements.
# * date: The date when the job was posted. As the data was scraped in 14 Aug 2023, the date is based on 14 Aug 2023.
# * Text: The full text of the job posting.
#
# ### Data Source
# The data was scraped from Indeed's website using Octoparse 8.

# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from IPython.display import display, HTML
from sklearn.decomposition import LatentDirichletAllocation
from collections import Counter
import numpy as np
import json
import plotly.express as px


# Further refine the cleaning process to remove remaining postal codes and identifiers
import re
# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Load stopwords
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Justin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Justin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Justin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 30)
# pd.set_option('display.width', 2)

# %%
df = pd.read_csv('DS_Job_ 2023 _ Indeed.csv')

# %%
df.head()
# Out:
#                                                Title  \
# 0  Work directly with project scientists in ICPAC...
# 1  Working to build effective data products that ...
# 2  Share your knowledge and enthusiasm for data s...
# 3  Experience using consumer behavioural data pre...
# 4  The group has been working at the forefront of...
#
#                                            Title_URL  \
# 0  https://uk.indeed.com/rc/clk?jk=ed884653280c20...
# 1  https://uk.indeed.com/rc/clk?jk=4a70c1254d0492...
# 2  https://uk.indeed.com/rc/clk?jk=f82754f93375de...
# 3  https://uk.indeed.com/rc/clk?jk=8bd213b8a32179...
# 4  https://uk.indeed.com/rc/clk?jk=1e82e1285bc0d7...
#
#                                               Title1           Company_name  \
# 0  PDRA in weather prediction, seasonal climate p...   University of Oxford
# 1                              Junior Data Scientist  Penguin Books Limited
# 2                                     Data Scientist                   Lidl
# 3                                     Data Scientist                 Disney
# 4  Departmental Lecturer in Artificial Intelligen...   University of Oxford
#
#                       Location         attribute_snippet  \
# 0                       Oxford  £35,308 - £43,155 a year
# 1                  London SW1V  £30,500 - £41,233 a year
# 2  Hybrid remote in London KT5  £56,100 - £78,100 a year
# 3                       London                       NaN
# 4                   Oxford OX3  £45,585 - £54,395 a year
#
#   metadata__divcontains_class_attribute_snippet  jobsnippet  \
# 0                                           NaN  scientists
# 1                                           NaN        data
# 2                                     Full-time        data
# 3                                           NaN        data
# 4                                 Full-time\n+1         NaN
#
#                                          jobsnippet2  \
# 0  Help set up an operational high-resolution for...
# 1                                                NaN
# 2  The goal is to analyse business processes thro...
# 3  Experience developing and scaling data science...
# 4                                                NaN
#
#                          date  \
# 0  Posted\nPosted 17 days ago
# 1   Posted\nPosted 3 days ago
# 2   Posted\nPosted 2 days ago
# 3   Posted\nPosted 4 days ago
# 4  Posted\nPosted 18 days ago
#
#                                                 Text
# 0  \n \n  Applications are invited for two Postdo...
# 1  Job detailsHere’s how the job details align wi...
# 2  Job detailsHere’s how the job details align wi...
# 3  \n \n  Data Scientist \n  \n  Apply Later \n  ...
# 4  Job detailsHere’s how the job details align wi...

# %%
#In order to have better visualization of the dataframe, rearange and rename the columns
new_order = ['Company_name','Title1','Title_URL','Location','attribute_snippet','metadata__divcontains_class_attribute_snippet','Title','jobsnippet','jobsnippet2','date','Text']
df = df.reindex(columns=new_order)

# Rename columns
column_name_mapping = {
    'Title': 'Job_Summary',
    'Title_URL': 'Job_URL',
    'Title1': 'Job_Title',
    'Company_name': 'Company_Name',
    'Location': 'Job_Location',
    'attribute_snippet': 'Salary_Range',
    'metadata__divcontains_class_attribute_snippet': 'Job_Type',
    'jobsnippet': 'Primary_Skill',
    'jobsnippet2': 'Job_Description_Snippet',
    'date': 'Posting_Date',
    'Text': 'Full_Job_Description'
}

df = df.rename(columns=column_name_mapping)

# %%
# Display the first few rows with the new column names
df.head()
# Out:
#             Company_Name                                          Job_Title  \
# 0   University of Oxford  PDRA in weather prediction, seasonal climate p...
# 1  Penguin Books Limited                              Junior Data Scientist
# 2                   Lidl                                     Data Scientist
# 3                 Disney                                     Data Scientist
# 4   University of Oxford  Departmental Lecturer in Artificial Intelligen...
#
#                                              Job_URL  \
# 0  https://uk.indeed.com/rc/clk?jk=ed884653280c20...
# 1  https://uk.indeed.com/rc/clk?jk=4a70c1254d0492...
# 2  https://uk.indeed.com/rc/clk?jk=f82754f93375de...
# 3  https://uk.indeed.com/rc/clk?jk=8bd213b8a32179...
# 4  https://uk.indeed.com/rc/clk?jk=1e82e1285bc0d7...
#
#                   Job_Location              Salary_Range       Job_Type  \
# 0                       Oxford  £35,308 - £43,155 a year            NaN
# 1                  London SW1V  £30,500 - £41,233 a year            NaN
# 2  Hybrid remote in London KT5  £56,100 - £78,100 a year      Full-time
# 3                       London                       NaN            NaN
# 4                   Oxford OX3  £45,585 - £54,395 a year  Full-time\n+1
#
#                                          Job_Summary Primary_Skill  \
# 0  Work directly with project scientists in ICPAC...    scientists
# 1  Working to build effective data products that ...          data
# 2  Share your knowledge and enthusiasm for data s...          data
# 3  Experience using consumer behavioural data pre...          data
# 4  The group has been working at the forefront of...           NaN
#
#                              Job_Description_Snippet  \
# 0  Help set up an operational high-resolution for...
# 1                                                NaN
# 2  The goal is to analyse business processes thro...
# 3  Experience developing and scaling data science...
# 4                                                NaN
#
#                  Posting_Date  \
# 0  Posted\nPosted 17 days ago
# 1   Posted\nPosted 3 days ago
# 2   Posted\nPosted 2 days ago
# 3   Posted\nPosted 4 days ago
# 4  Posted\nPosted 18 days ago
#
#                                 Full_Job_Description
# 0  \n \n  Applications are invited for two Postdo...
# 1  Job detailsHere’s how the job details align wi...
# 2  Job detailsHere’s how the job details align wi...
# 3  \n \n  Data Scientist \n  \n  Apply Later \n  ...
# 4  Job detailsHere’s how the job details align wi...

# %%
# Check for duplicated rows based on the 'Job_URL' column
duplicated_rows_by_url = df[df.duplicated(subset='Job_URL', keep=False)]

duplicated_rows_by_url[['Job_URL']]

# Count the frequency of each URL in the 'Job_URL' column
url_value_counts = duplicated_rows_by_url['Job_URL'].value_counts()

url_value_counts
# Out:
# Series([], Name: Job_URL, dtype: int64)

# %%
# Check for any NA values in the dataframe
df.isna().sum()
# Out:
# Company_Name                 0
# Job_Title                    0
# Job_URL                      0
# Job_Location                 0
# Salary_Range                90
# Job_Type                   116
# Job_Summary                 17
# Primary_Skill               97
# Job_Description_Snippet    186
# Posting_Date                 0
# Full_Job_Description         1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Company_Name             386 non-null    object
#  1   Job_Title                386 non-null    object
#  2   Job_URL                  386 non-null    object
#  3   Job_Location             386 non-null    object
#  4   Salary_Range             296 non-null    object
#  5   Job_Type                 270 non-null    object
#  6   Job_Summary              369 non-null    object
#  7   Primary_Skill            289 non-null    object
#  8   Job_Description_Snippet  200 non-null    object
#  9   Posting_Date             386 non-null    object
#  10  Full_Job_Description     385 non-null    object
# dtypes: object(11)
# memory usage: 33.3+ KB

# %% [markdown]
# ### Job Title

# %%
df['Job_Title'].unique()
# Out:
# array(['PDRA in weather prediction, seasonal climate prediction, and artificial intelligence/machine learning x 2 posts',
#        'Junior Data Scientist', 'Data Scientist',
#        'Departmental Lecturer in Artificial Intelligence for Healthcare Imaging',
#        'DATA SCIENTIST',
#        'Research Assistant / Research Fellow in Health Data Science',
#        'Assistant Professor AI, Innovation and Global Governance (EEI) - School of Government - 102147 - Grade 8',
#        'Lead Health Data Scientist',
#        'Associate Professor - Data Science (Research and Education) - School of Mathematics - 102259 - Grade 9',
#        'Post Doctoral Research Associate in Data Science and Machine Learning',
#        'Data Scientist, Marketing Effectiveness',
#        'Graduate Data Scientist',
#        'Data Scientist/Software Engineer (AI and Computer Vision)',
#        'Assistant Professor - Data Science (Research and Education) - School of Mathematics - 102274 - Grade 8',
#        'Lecturer/Senior Lecturer in Data Science (Physics/Astronomy/Mathematics)',
#        'Associate Professor AI, Innovation and Global Governance (Research and Education) - School of Government - 102148 - Grade 9',
#        'Graduate Data Scientist (Entry Level)',
#        'Microsoft Research@198 Residency Program – Deep Learning /Generative AI Researcher',
#        'Research Software Engineer in Machine Learning for UK SKA Regional Centre',
#        'Sports Modelling Data Scientist',
#        'STARS - Data Science Insights Team - Principal Data Scientist',
#        'Assistant Professorship in AI & Machine Learning in Disease',
#        '2024 Machine Learning Center of Excellence Summer Associate - NLP, Speech & Recommender Systems Internship – (6 months)',
#        'Professor in Artificial Intelligence and Machine Learning - Full time, Permanent',
#        'E-Commerce Senior Data Scientist, Governance and Experience',
#        'Senior Research Fellow Natural Language Processing - School of Government - 101730 - Grade 9',
#        'Research Fellow Natural Language Processing - School of Government - 101731 - Grade 8',
#        'Consultant - Manager, Data Science and Machine Learning, Defence and Security, SAMA',
#        'Data Scientist (AI)',
#        'Lecturer/ Senior Lecturer/ Reader (Natural Language Processing / Information Retrieval)',
#        '2024 Machine Learning Center of Excellence Summer Associate – Time Series & Reinforcement Learning Internship – (6 months)',
#        'Lecturer in Artificial Intelligence for Life Sciences (Teaching and Research)',
#        'Data scientist',
#        'Data Analyst / Date Scientist / Data Mining SAS / SQL – National/ Home based',
#        'Lecturer in Pervasive Data Science', 'Machine Learning & AI',
#        'Lecturer in Data Science & Analytics',
#        'Lecturer in Mathematical Machine Learning',
#        'Machine Learning Applied Scientist - NLP',
#        'Senior Staff Machine Learning Engineer - Play AI and Data',
#        'Senior Product Data Scientist',
#        'Quantitative Researcher (Data Science/Machine Learning/Mathematical Modelling)',
#        'Data Scientist / Quant Researcher',
#        'Machine Learning Research Engineer',
#        'Research Associate / Senior Research Associate in Machine Learning for Digital Infrastructures',
#        'Research Associate in AI for Health Data Sciences',
#        'Scientific Specialist - Research Statistical Data Scientist',
#        'Senior Data Scientist – NLP & MLOps',
#        'Data Scientist (KTP Associate)',
#        'Research Fellow in Machine Learning', 'Associate Data Scientist',
#        'Machine Learning Engineer', 'AI-Quant - Junior',
#        'Data Scientist – NLP',
#        'Scientific Specialist - Research Statistician',
#        'Junior Data Scientist - London',
#        'Data Science Industrial Placement 2023',
#        '(Machine Learning) R&D Engineer',
#        'Brand Health Tracking - Data Scientist', 'Lead Data Scientist',
#        'Data Scientist - Intern', 'Data Science Internship (Summer 2024)',
#        'Data Scientist (KTP Associate)/Research Assistant',
#        'Computational Scientist – (Machine Learning) Digital R&D Large Molecule Research',
#        'Research Associate in Speech Processing and Machine Learning for Detecting Cognitive Impairment',
#        'Environmental Data Scientist',
#        'Research Assistant/Associate - Natural Language Processing (Fixed Term)',
#        'Data Scientist - Commercial Sport', 'SMG | Data Scientist',
#        'Machine Learning Scientist',
#        'Research Scientists in Machine Learning(ML)',
#        'Smart Services Engineering – Graduate Data Science Engineer',
#        'Research Associate in Bioprocess Machine Learning and Hybrid Modelling',
#        'Machine Learning Engineers - UK Wide All Levels',
#        'Research Associate in Biomedical NLP',
#        'AIML- Machine Learning (Natural Language Understanding) Researcher, Siri',
#        'Lecturer/Senior Lecturer (Artificial Intelligence)',
#        'Machine Learning Research Scientist (Canada)',
#        'Post-Doctoral Research Associate in Medical Image Analysis and Causal Machine Learning',
#        'AI Developer (18-month fixed-term contract)',
#        'Reader in Data Science', 'Data Scientist Apprentice',
#        'Post-Doctoral Research Associate in Data Science and Statistical Genetics',
#        'Senior Data Scientist', 'Data Computational Scientist',
#        'Software Development Scientist with Machine Learning Specialisation',
#        'Research Assistant in Artificial Intelligence',
#        'Senior Data Scientist (AI/ML)',
#        'Scientist/Engineer for Machine Learning (multiple vacancies)',
#        'Data Scientist - London/Hybrid - Private Bank',
#        'Senior Clinical Data Scientist',
#        'Senior Data Scientist PhD – Canary Wharf',
#        'Data Scientist (Mobile Games)',
#        'Senior Machine Learning Researcher',
#        'Economics and Policy Statistician Analyst Graduate - Bristol August 2024',
#        'Data Scientist – Aerospace and Defence',
#        'Senior Python Engineer – AI Unicorn – London Scale Up',
#        'DATA SCIENCE CONSULTANT LONDON', 'Data Science Team Manager',
#        'Data Scientist - Scenario Modelling - ESO',
#        'BI and data science analyst (FTC)',
#        'Postdoctoral Research Scientist in Computational Neuroscience and Machine Learning',
#        'Marketing Data Science and Infrastructure, Media Lab',
#        'Lecturer / Senior Lecturer in Machine Learning',
#        'PDRA in Marine Remote Sensing and Machine Learning',
#        'Trainee Statistical Programmer',
#        'Lecturer - Professor Accelerating Data Science and AI (E&R and E&S)',
#        'Data Engineer/Scientist',
#        'Lecturer in Mathematics of Environmental Data Science',
#        'Research Associate in Machine Learning (2 Posts Available)',
#        'MSc Data Science Online Tutor',
#        'PhD Vacancy : Physics Informed Machine Learning for Ocean Forecasting',
#        'Global Business Improvement Data and Analytics manager',
#        'Postdoctoral Researcher in Population Data Science',
#        'Brand Health Tracking - Senior Data Scientist',
#        'Machine Learning Engineer - KTP Associate',
#        'Research Associate in Sensor Systems and Machine Learning for Delivering Next Generation Crops & Sustainable Food',
#        'Data Scientist/Machine Learning/Modelling/Algorith',
#        'Research Scientist (Machine Learning), London',
#        'Analytics & Digital Data Scientist',
#        'Senior Backend Engineer – Train in Machine Learning – Full Remote',
#        'Staff Data Scientist (Temporary)',
#        'Data Analyst / Data Scientist',
#        'Senior Data Scientist - United Kingdom (Remote)',
#        'Post Doctoral Researcher in Data Science',
#        'Data Scientist (Consultant)', 'Postdoctoral Data Scientist',
#        'Quantitative Data Scientist',
#        'Machine Learning Software Engineer - Tools',
#        'Data Scientist - R& Python',
#        'Machine Learning Engineer (ML Platform & Operations)',
#        'Defence Data Scientist',
#        'Principal Data Scientist - United Kingdom (Remote)',
#        'Chemist/Materials Scientist, Applied Science',
#        'ML Engineer (UAE)', 'Data Scientist/ Machine Learning',
#        'R&D, AI, Data Science, Computer Vision Software En',
#        'Data Scientist (Systematic Fund)',
#        'Machine Learning Algorithm Developer',
#        'Project Engineer – Artificial Intelligence Engineer for robotic developments',
#        'Applied AI ML - Senior Associate',
#        'HCUK Data Analytics & Models - Data Science',
#        'Machine Learning Bioinformatician',
#        'Natural Language Processing Developer',
#        'Professor in Computer Science/AI (Teaching and Research)',
#        'Data & Insights Analyst', 'Research Data Scientist/Analyst',
#        'Biomedical data scientist (inClinico)',
#        'Machine Learning Operations Engineer',
#        'Graduate Quantitative Trading Analyst / Data Scientist',
#        'DTS Degree and AI Apprentice',
#        'Python Engineer - Machine Learning, Investment Management',
#        'Researcher, Machine Learning Fairness',
#        'Unique PhD Graduate Program – Virtual Analytics Network (Remote)',
#        'Data Science And Analytics Lead', 'SENIOR DATA SCIENTIST',
#        'Senior Data Scientist (Research)',
#        'Industrial Impact Fellow - Data Science',
#        'Scientific Specialist - Consulting Statistician',
#        'Insights Data Scientist',
#        'Senior Applied Scientist, Machine Learning and Engineering',
#        'Principal Data Scientist - 12 Month FTC', 'Big Data Scientist',
#        'Director, Computational Biology, Oncology Data Science, Oncology R&D',
#        'Data Scientist - Manchester',
#        'DATA SCIENTIST / DATABASE ADMINISTRATOR',
#        'Behavioural Analysis & Support Senior Analyst',
#        'Data Science Apprentice', 'Machine Learning Researcher',
#        'Data Scientist, Office for Rare Conditions',
#        'AI Software Sales Specialist', 'Deep Learning HW Engineer',
#        'Research Associate in Environmental Policy and AI Evidence Communication',
#        'Director of Analytics and Data Science', 'Data Science Manager',
#        'Senior Data Scientist - Machine Learning & AI in Genomics',
#        'Data Scientist Lead (F/M/X)', 'Data for Analytics Product Owner',
#        'Senior Data Scientist/Developer',
#        'Machine Learning/Computer Vision Scientist (Home W',
#        'AI/Machine Learning developer',
#        'Research Assistant/ Research Fellow in Natural Language Processing with Quantum Technology',
#        'Graduate Apprentice, Energy Data Analyst',
#        'Software Engineer - Machine Learning (PyTorch)',
#        'Lecturer/Senior Lecturer in Hospitality Analytics',
#        'People Analytics Behavioral Scientist',
#        'MACHINE LEARNING SPECIALIST',
#        'Senior Data Scientist, Financial Crime',
#        'Systematic Machine Learning Quant Researcher',
#        'Research Fellow in Computational Design, Machine Learning and Designer-Computer Interaction in Architecture',
#        'Staff Data Scientist', 'Data Analytics Engineer',
#        'Market Research Data Scientist',
#        'Research Fellow in Machine Learning x2', 'graduate ai developer',
#        'Senior Data Scientist - NLP',
#        'Senior Data Scientist/ Machine Learning Developer',
#        'Postdoctoral Research Assistant in Machine Learning & Biomedical Imaging',
#        'Natural Language Processing (NLP) Researcher',
#        'Lecturer/Senior Lecturer in Natural Language Processing',
#        'Senior Machine Learning Scientist (Defence and Security)',
#        'Senior Machine Learning Engineer / Data Scientist',
#        'Senior/Lead Data Analytics Consultant - Fashion and Luxury goods',
#        'Trainee Specialist Consultant (AI & Data Science)',
#        'CTO - Machine Learning Scale-Up', 'Decision Scientist Lead',
#        'Data Science Manager - CVU',
#        'Data Analysis and Machine Learning Specialist',
#        'Pricing Data Scientist', 'Senior Machine Learning Engineer',
#        'Senior Data Scientist, Operations',
#        'Quantitative Research Analyst',
#        'Machine Learning Engineer – Research and Development',
#        'Principal - Machine Learning',
#        'Research Associate in Machine Learning of Nonequilibrium Processes',
#        'Quantitative Researcher in Natural Language Processing (NLP)',
#        'Data Scientist Python Software - London',
#        'Research Led Start Up Recruiting Machine Learning Researcher',
#        'Data Science Team Lead',
#        'Principal Research Scientist (Machine Learning), London',
#        'Data Scientist - FILLED',
#        'Senior Data & Analytics Technical Director - Machine Learning/Artificial Intelligence (ML/AI)',
#        'Machine Learning Software Engineer', 'Research Scientist, NLP',
#        'Principal Clinical Data Scientist South Africa or UK',
#        'Data Scientist - Consultancy',
#        'Senior Software Engineer - Machine Learning (Ads) (Remote - United Kingdom)',
#        'Data Scientists | Data Analysts | Data Engineers',
#        'Visual Analytics Consultant', 'Biomedical data scientist',
#        'Data Scientist | Telecoms Powerhouse.',
#        'Contract Data Science and Machine Learning SME IRC188351',
#        'Behavioural Data Scientist | Leading Consultancy.',
#        'Machine Learning Engineer - Location UK or Israel',
#        'Machine Learning Engineer – NLP Large Models',
#        'Post-Doctoral Applied Mathematician/Quantitative Scientist',
#        'Lead Data Scientist – AI', 'Research Data Scientist',
#        'Data Science industrialisation Consultant',
#        'Applied Machine Learning Scientist',
#        'AI Research Scientist - (Leadership)',
#        'AI, Machine Learning, Block chain - Python Developer Wanted!',
#        'Data Analyst / Scientist',
#        'Natural Language Processing Engineers',
#        'Machine Learning Engineer; Computer Vision, Data S',
#        'Quant Trading Fund Hiring Deep Learning Researcher / Global',
#        'Data Scientist – Pricing', 'Data Science Consultant',
#        'Principal Data Scientist', 'Analytics Developer',
#        'Research Fellow in Computational Statistics and Machine Learning for Clinical Modelling (CHIMERA)',
#        'Senior / Lead Data Scientist', 'Sr AI/Data Science Engineer',
#        'Senior Data Scientist- Python, SQL, ML & GCP - Fully Remote',
#        'Data Modeller', 'Credit Data Scientist',
#        'Applied AI ML Associate Sr',
#        'Business Intelligence & Data Analytics Manager',
#        'Software Engineer (Machine Learning), London',
#        'PHD NLP Quant Specialists',
#        'Data Scientist / Database Administrator', 'DATA SCIENCE ENGINEER',
#        'Technical HR Data and Analytics Manager',
#        'Senior Software Engineer, Machine Learning',
#        'Research Software Engineer (Neuroscience/Machine Learning)',
#        'Machine Learning Engineer C++ (6 Month Contract)',
#        'Senior Machine Learning Engineer - MarTech',
#        'NLP Quant Specialists', 'Data Analyst/Scientist',
#        'Director of Data Science, Operations',
#        'Senior Data Science Engineer', 'Artificial Intelligence lead',
#        'Senior Data Scientist - 1x/month in London - up to GBP80k',
#        'Senior/Lead Data Scientist',
#        'Senior Data Scientist - AI Specialist', 'Data Science Lead',
#        'Computational Scientist Lead – (Machine Learning) Digital R&D Large Molecule Research',
#        'Data Scientist – Gaming Production House',
#        'Head of BI & Data Science', 'Big Data Engineer',
#        'Junior Analytics Specialist',
#        'Senior Consultant Data & Analytics',
#        'Machine Learning Engineer - LLMs, Fintech', 'Big Data Analyst',
#        'AI-Quant - Intermediate', 'AI Specialist',
#        'Senior Applied Data Scientist | Causal AI.',
#        'Principal Data Scientist (GG13)', 'Lead AI/ML Engineer'],
#       dtype=object)

# %%
df_job_title = df[['Job_Title']]

# %% [markdown]
# Extracts up to 20 keywords that are common across the titles using CountVectorizer.
#
# This gives  a nice set of keywords that represent the core topics and themes in the job titles data.

# %%
# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    text=text.replace("/"," ")
    # Remove non-alphabetic characters
    text = ''.join([char for char in text if char.isalpha() or char.isspace()])
    # Lemmatize and remove stopwords
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(words)

# Apply preprocessing to the job titles
df_job_title['Processed_Title'] = df_job_title['Job_Title'].apply(preprocess_text)

# Extract keywords using CountVectorizer
vectorizer = CountVectorizer(max_features=20)
X = vectorizer.fit_transform(df_job_title['Processed_Title'])
keywords = vectorizer.get_feature_names_out()

keywords
# Out:
# C:\Users\Justin\AppData\Local\Temp\ipykernel_5880\3104144893.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_job_title['Processed_Title'] = df_job_title['Job_Title'].apply(preprocess_text)
# array(['ai', 'analyst', 'analytics', 'associate', 'data', 'engineer',
#        'language', 'lead', 'learning', 'lecturer', 'machine', 'manager',
#        'nlp', 'research', 'researcher', 'science', 'scientist', 'senior',
#        'software', 'specialist'], dtype=object)

# %%
def categorize_job_titles(df, column_name):
    """
    Preprocess and categorize job titles based on domain and seniority.
    
    Parameters:
    - df: DataFrame containing the job titles.
    - column_name: Column name in the dataframe that contains the job titles.
    
    Returns:
    - DataFrame with additional columns for category, and refined seniority.
    """
    
    # Function to preprocess text
    def preprocess_text(text):
        # Convert to lowercase
        text = text.lower()
        text = text.replace("/", " ")
        # Remove non-alphabetic characters
        text = ''.join([char for char in text if char.isalpha() or char.isspace()])
        # Lemmatize and remove stopwords
        words = text.split()
        words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
        return ' '.join(words)
    
    # Define a function to categorize job titles based on seniority
    def refined_categorize_seniority(title):
        if 'phd' in title:
            return 'PhD'
        elif any(term in title for term in["junior", "jr", "entry", "graduate", "trainee"]):
            return "Entry-level"
        elif any(term in title for term in ["senior researcher", "senior research"]):
            return "Senior Research"
        elif "senior lecturer" in title or "associate professor" in title:
            return "Senior Academic"
        elif any(term in title for term in ["senior", "sr", "snr"]):
            return "Senior"
        elif any(term in title for term in ["post-doc","postdoctoral","postdoctoral research","postdoctoral",'post doctoral']):
            return "Post-doc"
        elif any(term in title for term in ["fellow", "research fellow","research associate"]):
            return "Research Fellow/Associate"
        elif "research assistant" in title:
            return "Research Assistant"
        elif "lecturer" in title and not "senior lecturer" in title:
            return "Lecturer"
        elif any(term in title for term in ["lead", "head"]) and not any(term in title for term in ["manager", "director"]) and not any(term in title for term in ["consultancy", "leadership"]):
            return "Lead/Head"
        elif "manager" in title:
            return "Manager"
        elif "director" in title:
            return "Director"
        elif "intern" in title:
            return "Intern"
        elif "principal" in title:
            return "Principal"
        elif "associate" in title or "assistant" in title:
            return "Assistant/Associate"
        elif "research" in title:
            return "Researcher"
        elif "professor" in title:
            return "Lecturer"
        elif "tutor" in title:
            return "Tutor"
        else:
            return "Mid-Level"
        
    # Define a function to categorize job titles based on keywords
    # Adjust the domain categorization function to prioritize Machine Learning/AI when both categories are present
    def categorize_title(title):
        if any(term in title for term in ["machine", "learning", "ai","artificial intelligence","deep learning","artificial","ml"]):
            return "Machine Learning/AI"
        elif "nlp" in title or "natural language processing" in title:
            return "NLP"
        elif any(term in title for term in ["data", "analytics", "scientist", "science"]):
            return "Data Science"
        else:
            return "Other"
    
    # Apply preprocessing to the job titles
    df['Processed_Title'] = df[column_name].apply(preprocess_text)
    
    # Apply the domain categorization function to the preprocessed job titles
    df['Category'] = df['Processed_Title'].apply(categorize_title)
    
    # Apply the refined seniority categorization function to the preprocessed job titles
    df['Refined_Seniority'] = df['Processed_Title'].apply(refined_categorize_seniority)
    df.drop(columns=['Processed_Title'], inplace=True)
    return df

# %%
df = categorize_job_titles(df, 'Job_Title')

# %%
df.head()
# Out:
#             Company_Name                                          Job_Title  \
# 0   University of Oxford  PDRA in weather prediction, seasonal climate p...
# 1  Penguin Books Limited                              Junior Data Scientist
# 2                   Lidl                                     Data Scientist
# 3                 Disney                                     Data Scientist
# 4   University of Oxford  Departmental Lecturer in Artificial Intelligen...
#
#                                              Job_URL  \
# 0  https://uk.indeed.com/rc/clk?jk=ed884653280c20...
# 1  https://uk.indeed.com/rc/clk?jk=4a70c1254d0492...
# 2  https://uk.indeed.com/rc/clk?jk=f82754f93375de...
# 3  https://uk.indeed.com/rc/clk?jk=8bd213b8a32179...
# 4  https://uk.indeed.com/rc/clk?jk=1e82e1285bc0d7...
#
#                   Job_Location              Salary_Range       Job_Type  \
# 0                       Oxford  £35,308 - £43,155 a year            NaN
# 1                  London SW1V  £30,500 - £41,233 a year            NaN
# 2  Hybrid remote in London KT5  £56,100 - £78,100 a year      Full-time
# 3                       London                       NaN            NaN
# 4                   Oxford OX3  £45,585 - £54,395 a year  Full-time\n+1
#
#                                          Job_Summary Primary_Skill  \
# 0  Work directly with project scientists in ICPAC...    scientists
# 1  Working to build effective data products that ...          data
# 2  Share your knowledge and enthusiasm for data s...          data
# 3  Experience using consumer behavioural data pre...          data
# 4  The group has been working at the forefront of...           NaN
#
#                              Job_Description_Snippet  \
# 0  Help set up an operational high-resolution for...
# 1                                                NaN
# 2  The goal is to analyse business processes thro...
# 3  Experience developing and scaling data science...
# 4                                                NaN
#
#                  Posting_Date  \
# 0  Posted\nPosted 17 days ago
# 1   Posted\nPosted 3 days ago
# 2   Posted\nPosted 2 days ago
# 3   Posted\nPosted 4 days ago
# 4  Posted\nPosted 18 days ago
#
#                                 Full_Job_Description             Category  \
# 0  \n \n  Applications are invited for two Postdo...  Machine Learning/AI
# 1  Job detailsHere’s how the job details align wi...         Data Science
# 2  Job detailsHere’s how the job details align wi...         Data Science
# 3  \n \n  Data Scientist \n  \n  Apply Later \n  ...         Data Science
# 4  Job detailsHere’s how the job details align wi...  Machine Learning/AI
#
#   Refined_Seniority
# 0         Mid-Level
# 1       Entry-level
# 2         Mid-Level
# 3         Mid-Level
# 4          Lecturer

# %% [markdown]
# ### Job Location

# %%
df['Job_Location'].unique()
# Out:
# array(['Oxford', 'London SW1V', 'Hybrid remote in London KT5', 'London',
#        'Oxford OX3', 'Remote', 'Hybrid remote in Guildford', 'Exeter EX2',
#        'Birmingham', 'Lincoln', 'Hybrid remote in London',
#        'Hybrid remote in Didcot OX11', 'London EC1V', 'Hatfield',
#        'Aberdeen', 'Cambridge', 'Hybrid remote in Manchester M13',
#        'Hybrid remote in London E14', 'Hybrid remote in Bristol',
#        'Edinburgh', 'Glasgow', 'Leicester LE1',
#        'Hybrid remote in London NW9', 'England', 'Remote in London',
#        'Sheffield', 'Remote in London N1', 'Remote in England',
#        'Bristol BS8', 'Harpenden AL5',
#        'Remote in Newcastle upon Tyne\n+1 location',
#        'Hybrid remote in Leicestershire', 'Hybrid remote in Bristol BS37',
#        'West Midlands', 'London W1D', 'Hybrid remote in Manchester',
#        'Remote in Glasgow G2', 'Letchworth', 'Remote in London E1W',
#        'Norwich', 'Wigan WN1', 'Bristol', 'Nottingham', 'Newbridge NP11',
#        'Hybrid remote in Edinburgh', 'Hybrid remote in Leeds',
#        'Hybrid remote in Nottingham NG2', 'Leeds', 'Dundee',
#        'Hammersmith', 'Manchester', 'Hybrid remote in Charlbury',
#        'Hybrid remote in Sidcup', 'High Wycombe HP10', 'Wolverhampton',
#        'Hybrid remote in Newcastle upon Tyne', 'Thame', 'Warrington',
#        'Hybrid remote in Reading', 'Plymouth PL6', 'London SE1',
#        'Bristol BS1\n+7 locations', 'Hybrid remote in Cambridge',
#        'Hybrid remote in Belfast BT1', 'Remote in Warwick CV34',
#        'Hullavington', 'London W4', 'Reading RG6', 'Exeter',
#        'Hybrid remote in London E2', 'Remote in London WC1E',
#        'Oxford OX1', 'Belfast BT7', 'East of England',
#        'Hybrid remote in Gaydon',
#        'Hybrid remote in Bristol\n+2 locations',
#        'Remote in United Kingdom', 'Bollington SK10', 'Guildford',
#        'Hybrid remote in Southampton', 'Remote in London\n+1 location',
#        'London SE11', 'London EC2A', 'Birkenhead',
#        'London W1D\n+1 location', 'West London', 'South West',
#        'London EC1Y', 'Epsom', 'Remote in Bath\n+2 locations',
#        'Hybrid remote in Stevenage SG1\n+1 location',
#        'University of Warwick', 'London E14', 'Hybrid remote in Redhill',
#        'Oxfordshire', 'Remote in Harpenden AL5',
#        'Hybrid remote in Cambridgeshire', 'London W2', 'Leicester',
#        'Brentwood', 'Remote in Guernsey', 'Hybrid remote in Lancashire',
#        'Remote in Manchester\n+1 location',
#        'Hybrid remote in London EC2A', 'Cornwall',
#        'Hybrid remote in London E1', 'Hybrid remote in Osterley',
#        'Hybrid remote in West London', 'Cambridge CB2', 'Colchester',
#        'Leeds LS1', 'Dunstable LU5', 'Winnersh RG41', 'Remote in Swindon',
#        'Remote in Haywards Heath', 'Wales', 'Perth PH1',
#        'Remote in St Albans', 'Remote in Birmingham\n+3 locations',
#        'Headington', 'Hybrid remote in Coventry', 'Bradford', 'Abingdon',
#        'Chelmsford', 'Hybrid remote in Brighton and Hove', 'Holborn',
#        'Sunderland', 'Hybrid remote in Leeds LS11',
#        'Hybrid remote in Redditch', 'Hook', 'London\n+1 location',
#        'Hybrid remote in South Kensington', 'Boston', 'London NE8',
#        'Manchester\n+2 locations',
#        'Hybrid remote in Edinburgh\n+1 location',
#        'High Wycombe\n+11 locations', 'Bracknell',
#        'Hybrid remote in Greater London', 'Remote in Tadworth',
#        'West London\n+2 locations', 'Hybrid remote in Slough',
#        'Milton Keynes', 'Hybrid remote in Aberdeen', 'Cambridge CB4',
#        'Hybrid remote in Glasgow', 'Hybrid remote in Staines-upon-Thames',
#        'Hybrid remote in Manchester M1',
#        'Hybrid remote in Leeds LS1\n+5 locations',
#        'Reading\n+13 locations', 'Remote in Lowestoft',
#        'Hybrid remote in Dunstable LU5', 'Hybrid remote in Derby',
#        'Reading', 'London W1S', 'Remote in Kingston upon Hull', 'Malvern'],
#       dtype=object)

# %%
def clean_job_location(df):
    """
    Cleans the 'Job_Location' column of the dataframe and adds a 'Remote' column.
    
    Parameters:
    - df: DataFrame containing the job location details.
    
    Returns:
    - DataFrame with cleaned 'Job_Location' column and a new 'Remote' column.
    """
    
    # Create a new 'Remote' column based on the presence of the words "Remote" and "Hybrid"
    df['Remote'] = 'Not remote'
    df.loc[df['Job_Location'].str.contains('Remote', case=False), 'Remote'] = 'Remote'
    df.loc[df['Job_Location'].str.contains('Hybrid', case=False), 'Remote'] = 'Hybrid'
    
    # Clean up the 'Job_Location' column
    # df['Job_Location'] = df['Job_Location'].str.replace('Remote in ', '', case=False).str.replace('Hybrid remote in ', '', case=False)
    df['Job_Location'] = df['Job_Location'].str.replace('Remote in ', '').str.replace('Hybrid remote in ', '')
    

    def clean_location(location):
        # Remove any characters after city names like postal codes or alphanumeric characters
        location = re.split('([A-Z]{1,2}[0-9R][0-9A-Z]?)', location)[0]
        
        # Handle locations with multiple cities to keep only the primary city
        location = location.split('\n')[0]
        
        # Handle special cases
        if "University of" in location:
            location = location.replace("University of ", "")
        
      # Remove any unnecessary or redundant words
        for redundant_word in ["+1 location", "+2 locations", "+3 locations"]:
            location = location.replace(redundant_word, "")
        
        return location.strip()
    
    df["Job_Location"] = df["Job_Location"].apply(clean_location)
    
    return df

# %%
df = clean_job_location(df)

# %%
df['Job_Location'].unique()
# Out:
# array(['Oxford', 'London', 'Remote', 'Guildford', 'Exeter', 'Birmingham',
#        'Lincoln', 'Didcot', 'Hatfield', 'Aberdeen', 'Cambridge',
#        'Manchester', 'Bristol', 'Edinburgh', 'Glasgow', 'Leicester',
#        'England', 'Sheffield', 'Harpenden', 'Newcastle upon Tyne',
#        'Leicestershire', 'West Midlands', 'Letchworth', 'Norwich',
#        'Wigan', 'Nottingham', 'Newbridge', 'Leeds', 'Dundee',
#        'Hammersmith', 'Charlbury', 'Sidcup', 'High Wycombe',
#        'Wolverhampton', 'Thame', 'Warrington', 'Reading', 'Plymouth',
#        'Belfast', 'Warwick', 'Hullavington', 'East of England', 'Gaydon',
#        'United Kingdom', 'Bollington', 'Southampton', 'Birkenhead',
#        'West London', 'South West', 'Epsom', 'Bath', 'Stevenage',
#        'Redhill', 'Oxfordshire', 'Cambridgeshire', 'Brentwood',
#        'Guernsey', 'Lancashire', 'Cornwall', 'Osterley', 'Colchester',
#        'Dunstable', 'Winnersh', 'Swindon', 'Haywards Heath', 'Wales',
#        'Perth', 'St Albans', 'Headington', 'Coventry', 'Bradford',
#        'Abingdon', 'Chelmsford', 'Brighton and Hove', 'Holborn',
#        'Sunderland', 'Redditch', 'Hook', 'South Kensington', 'Boston',
#        'Bracknell', 'Greater London', 'Tadworth', 'Slough',
#        'Milton Keynes', 'Staines-upon-Thames', 'Lowestoft', 'Derby',
#        'Kingston upon Hull', 'Malvern'], dtype=object)

# %% [markdown]
# ### Salary_Range

# %%
df['Salary_Range'].unique()
# Out:
# array(['£35,308 - £43,155 a year', '£30,500 - £41,233 a year',
#        '£56,100 - £78,100 a year', nan, '£45,585 - £54,395 a year',
#        '£50,000 - £70,000 a year', '£30,487 - £37,099 a year',
#        '£43,742 - £50,056 a year', '£51,306 - £59,450 a year',
#        '£56,021 - £64,914 a year', '£37,099 a year', 'Full-time',
#        '£20,595 - £23,121 a year', '£36,333 - £43,155 a year',
#        'Fixed term contract', '£36,024 - £56,021 a year',
#        '£60,000 - £75,000 a year', '£61,000 - £67,100 a year',
#        '£45,585 - £57,696 a year', '£28,000 - £30,000 a year',
#        '£65,000 - £95,000 a year', '£54,421 - £63,059 a year',
#        '£44,414 - £52,841 a year', '£64,914 a year',
#        '£44,263 - £54,395 a year', '£32,978 - £39,691 a year',
#        '£80,000 a year', '£25,000 - £85,000 a year',
#        '£46,974 - £56,021 a year', '£60,000 a year',
#        '£45,791 - £50,855 a year', '£39,347 - £54,395 a year',
#        '£50,000 - £90,000 a year', '£37,099 - £41,732 a year',
#        '£37,386 - £43,155 a year', '£37,890 - £41,438 a year',
#        '£60,000 - £95,000 a year', '£37,295 - £44,724 a year',
#        '£44,414 - £54,421 a year', '£60,000 - £70,000 a year',
#        '£27,000 - £32,000 a year', '£60,000 - £80,000 a year',
#        '£29,842 - £32,315 a year', '£35,000 - £50,000 a year',
#        'Temporary contract', '£40,000 - £70,000 a year',
#        '£35,392 - £42,618 a year', 'Internship', '£25,702 a year',
#        '£51,706 - £58,210 a year', '£34,000 a year',
#        '£36,333 - £37,386 a year', '£29,733 - £31,553 a year',
#        '£29,605 - £33,966 a year', '£34,173 - £44,021 a year',
#        '£65,000 - £70,000 a year', '£28,131 - £32,411 a year',
#        '£32,000 - £45,000 a year', '£45,593 - £53,630 a year',
#        '£39,347 - £45,585 a year', 'Up to £65,000 a year',
#        '£45,192 - £49,280 a year', '£54,949 - £63,673 a year',
#        '£30,000 a year', '£55,048 - £61,164 a year',
#        '£39,748 - £44,166 a year', '£65,000 - £80,000 a year',
#        '£70,000 - £85,000 a year', 'Full-time\n+1', '£400 - £475 a day',
#        '£600 a day', '£60,000 - £90,000 a year',
#        '£90,000 - £100,000 a year', '£70,580 - £89,460 a year',
#        '£66,000 a year', '£36,024 - £44,263 a year',
#        '£44,414 - £66,890 a year', '£33,966 - £37,099 a year',
#        'Permanent', '£45,585 - £56,021 a year',
#        '£37,099 - £44,263 a year', '£1,330 a month',
#        '£33,904 - £41,309 a year', '£28,000 - £40,000 a year',
#        '£45,000 - £75,000 a year', '£37,000 - £55,000 a year',
#        '£80,000 - £110,000 a year', '£33,966 - £39,347 a year',
#        '£80,000 - £90,000 a year', '£35,000 - £40,000 a year',
#        '£40,000 - £45,000 a year', '£35,000 - £36,000 a year',
#        '£35,000 - £70,000 a year', '£40,000 - £50,000 a year',
#        'Up to £55,000 a year', 'Part-time', '£33,348 - £43,155 a year',
#        '£34,000 - £39,000 a year', '£80,000 - £100,000 a year',
#        '£68,000 a year', '£17,000 a year', '£800 - £900 a day',
#        'Up to £735 a day', '£65,000 - £75,000 a year', '£41,732 a year',
#        '£85,000 a year', '£75,000 - £90,000 a year',
#        '£75,000 - £85,000 a year', '£36,500 - £54,700 a year',
#        '£25,000 a year', '£39,347 - £44,263 a year',
#        '£97,000 - £120,000 a year', '£65,000 a year', '£400 - £600 a day',
#        '£7 an hour', '£20,609 a year', '£44,414 - £64,946 a year',
#        '£50,000 - £60,000 a year', '£34,314 - £37,386 a year',
#        '£35,000 - £45,000 a year', '£25,000 - £30,000 a year',
#        '£46,974 - £66,857 a year', '£160,000 - £200,000 a year',
#        '£100,000 - £140,000 a year', 'Permanent\n+1', '£350 - £500 a day',
#        '£75,000 a year', '£50,000 - £100,000 a year',
#        '£22,000 - £50,000 a year', '£40,000 - £60,000 a year',
#        'From £65,000 a year', '£33,000 - £37,000 a year',
#        '£100,000 - £120,000 a year', '£38,052 - £45,354 a year',
#        '£50,000 - £55,000 a year', '£22.50 an hour',
#        '£65,000 - £85,000 a year', '£30,000 - £55,000 a year',
#        '£36,611 a year', '£60,000 - £65,000 a year',
#        '£700 - £800 a month', '£500 - £800 a day',
#        '£45,000 - £55,000 a year', '£77,600 - £116,400 a year',
#        '£56,001 - £72,000 a year', 'Up to £80,000 a year',
#        '£500 - £600 a week', '£37,295 - £41,425 a year',
#        '£100,000 a year', '£80,000 - £120,000 a year', '£140,000 a year',
#        '£90,000 a year', '£300 - £450 a day',
#        '£120,000 - £150,000 a year'], dtype=object)

# %%
# Define a function to extract time units from the Salary_Range column
def extract_info_from_salary(salary):
    # Identify time unit
    time_unit = None
    if "year" in str(salary):
        time_unit = "Year"
    elif "month" in str(salary):
        time_unit = "Month"
    elif "week" in str(salary):
        time_unit = "Week"
    elif "day" in str(salary):
        time_unit = "Day"
    elif "hour" in str(salary):
        time_unit = "Hour"
    return time_unit
    
# Define the extract_salary function
def extract_salary(text):
    if not isinstance(text, str):
        return None  # or return an empty string, based on preference

    # Find the range with or without comma in numbers
    matches = re.findall(r'£\d{1,3}(?:,\d{3})*(?:\s*-\s*£\d{1,3}(?:,\d{3})*)?', text)
    return ' '.join(matches).strip()

def convert_to_int(salary):
    numbers = re.findall(r'\d+(?:[,_]\d+)*', salary)
    numbers = [int(num.replace(',', '')) for num in numbers]

    if '-' in salary:
        return numbers
    
    if not numbers:
        return None
        
    return numbers[0]

def fill_empty_and_na_values(df):
    """
    Fills missing and empty values in the 'Salary_Range' and 'Salary_Period' columns.
    
    Parameters:
    - df: DataFrame containing the job salary details.
    
    Returns:
    - DataFrame with filled values in 'Salary_Range' and 'Salary_Period' columns.
    """
    
    df['Salary_Range'].fillna("Not specified", inplace=True)
    df['Salary_Period'].fillna("Not specified", inplace=True)
    df['Salary_Range'].replace('', 'Not specified', inplace=True)
 
    return df

# %%
# Apply the function to the Salary_Range column
df['Salary_Period'] = df['Salary_Range'].map(extract_info_from_salary)
df['Salary_Range'] = df['Salary_Range'].apply(extract_salary)
# Fill the empty values with "Not specified"
df = fill_empty_and_na_values(df)

# %%
# Convert the salary range to a list of integers
df['Salary_Range'] = df['Salary_Range'].apply(convert_to_int)

# %%
# Check for empty values in the Salary_Range column
df.head()
# Out:
#             Company_Name                                          Job_Title  \
# 0   University of Oxford  PDRA in weather prediction, seasonal climate p...
# 1  Penguin Books Limited                              Junior Data Scientist
# 2                   Lidl                                     Data Scientist
# 3                 Disney                                     Data Scientist
# 4   University of Oxford  Departmental Lecturer in Artificial Intelligen...
#
#                                              Job_URL Job_Location  \
# 0  https://uk.indeed.com/rc/clk?jk=ed884653280c20...       Oxford
# 1  https://uk.indeed.com/rc/clk?jk=4a70c1254d0492...       London
# 2  https://uk.indeed.com/rc/clk?jk=f82754f93375de...       London
# 3  https://uk.indeed.com/rc/clk?jk=8bd213b8a32179...       London
# 4  https://uk.indeed.com/rc/clk?jk=1e82e1285bc0d7...       Oxford
#
#      Salary_Range       Job_Type  \
# 0  [35308, 43155]            NaN
# 1  [30500, 41233]            NaN
# 2  [56100, 78100]      Full-time
# 3            None            NaN
# 4  [45585, 54395]  Full-time\n+1
#
#                                          Job_Summary Primary_Skill  \
# 0  Work directly with project scientists in ICPAC...    scientists
# 1  Working to build effective data products that ...          data
# 2  Share your knowledge and enthusiasm for data s...          data
# 3  Experience using consumer behavioural data pre...          data
# 4  The group has been working at the forefront of...           NaN
#
#                              Job_Description_Snippet  \
# 0  Help set up an operational high-resolution for...
# 1                                                NaN
# 2  The goal is to analyse business processes thro...
# 3  Experience developing and scaling data science...
# 4                                                NaN
#
#                  Posting_Date  \
# 0  Posted\nPosted 17 days ago
# 1   Posted\nPosted 3 days ago
# 2   Posted\nPosted 2 days ago
# 3   Posted\nPosted 4 days ago
# 4  Posted\nPosted 18 days ago
#
#                                 Full_Job_Description             Category  \
# 0  \n \n  Applications are invited for two Postdo...  Machine Learning/AI
# 1  Job detailsHere’s how the job details align wi...         Data Science
# 2  Job detailsHere’s how the job details align wi...         Data Science
# 3  \n \n  Data Scientist \n  \n  Apply Later \n  ...         Data Science
# 4  Job detailsHere’s how the job details align wi...  Machine Learning/AI
#
#   Refined_Seniority      Remote  Salary_Period
# 0         Mid-Level  Not remote           Year
# 1       Entry-level  Not remote           Year
# 2         Mid-Level      Hybrid           Year
# 3         Mid-Level  Not remote  Not specified
# 4          Lecturer  Not remote           Year

# %%
# Average salary
df['Average_Salary'] = df['Salary_Range'].apply(lambda x: np.mean(x) if x else np.nan)

# %% [markdown]
# ### Job_Type

# %%
df['Job_Type'].unique()
# Out:
# array([nan, 'Full-time', 'Full-time\n+1', 'Permanent', 'Full-time\n+2',
#        'Part-time', 'Fixed term contract', 'Temporary contract',
#        'Internship', 'Freelance', 'Overtime', 'Apprenticeship',
#        'Permanent\n+1'], dtype=object)

# %%
def clean_job_type(job_type):
    if isinstance(job_type, str):
        return re.sub(r'\n\+\d', '', job_type).strip()
    return job_type
def fill_empty_Job_Type(df):
    """
    Fills missing and empty values in the 'Salary_Range' and 'Salary_Period' columns.
    
    Parameters:
    - df: DataFrame containing the job salary details.
    
    Returns:
    - DataFrame with filled values in 'Salary_Range' and 'Salary_Period' columns.
    """
    
    df['Job_Type'].fillna("Not specified", inplace=True)  
    return df

# %%
# Apply the updated function
df['Job_Type'] = df['Job_Type'].apply(clean_job_type)
df=fill_empty_Job_Type(df)

# %%
df['Job_Type'].unique()
# Out:
# array(['Not specified', 'Full-time', 'Permanent', 'Part-time',
#        'Fixed term contract', 'Temporary contract', 'Internship',
#        'Freelance', 'Overtime', 'Apprenticeship'], dtype=object)

# %%
df.isna().sum()
# Out:
# Company_Name                 0
# Job_Title                    0
# Job_URL                      0
# Job_Location                 0
# Salary_Range               199
# Job_Type                     0
# Job_Summary                 17
# Primary_Skill               97
# Job_Description_Snippet    186
# Posting_Date                 0
# Full_Job_Description         1
# Category                     0
# Refined_Seniority            0
# Remote                       0
# Salary_Period                0
# Average_Salary             199
# dtype: int64

# %% [markdown]
# ### Posting_Date

# %%
df['Posting_Date'].unique()
# Out:
# array(['Posted\nPosted 17 days ago', 'Posted\nPosted 3 days ago',
#        'Posted\nPosted 2 days ago', 'Posted\nPosted 4 days ago',
#        'Posted\nPosted 18 days ago', 'Posted\nPosted 30+ days ago',
#        'Posted\nPosted 11 days ago', 'Posted\nPosted 19 days ago',
#        'Posted\nPosted 16 days ago', 'Posted\nPosted 5 days ago',
#        'Posted\nPosted 26 days ago', 'Posted\nPosted 6 days ago',
#        'Posted\nPosted 7 days ago', 'Posted\nPosted 30 days ago',
#        'Posted\nPosted 23 days ago', 'Employer\nActive 26 days ago',
#        'Posted\nPosted 10 days ago', 'Posted\nPosted 25 days ago',
#        'Posted\nPosted 9 days ago', 'Posted\nPosted 8 days ago',
#        'Posted\nPosted 22 days ago', 'Posted\nPosted 24 days ago',
#        'Posted\nPosted 20 days ago', 'Posted\nPosted 14 days ago',
#        'Posted\nPosted 12 days ago', 'Posted\nPosted 1 day ago',
#        'Posted\nPosted 28 days ago', 'Posted\nPosted 27 days ago',
#        'Posted\nPosted 13 days ago', 'Employer\nActive 14 days ago',
#        'Employer\nActive 5 days ago'], dtype=object)

# %%
# Cleaning Posting Date
def extract_days(text):
    # Extract number from the string
    result = re.search(r'(\d+)', text)
    if result:
        return int(result.group(1))
    return None

# %%
df['Posting_Date'] = df['Posting_Date'].apply(extract_days)

# %% [markdown]
# ### Rearrange the column

# %%
new_order = ['Job_URL','Company_Name','Job_Title','Category','Refined_Seniority','Remote','Job_Location','Salary_Range','Salary_Period','Average_Salary','Job_Type','Posting_Date','Job_Summary','Primary_Skill','Job_Description_Snippet','Full_Job_Description']
# df_copy = df.copy()
# df_copy =df_copy.reindex(columns=new_order)
df = df.reindex(columns=new_order)

# %%
df.isna().sum()
# Out:
# Job_URL                      0
# Company_Name                 0
# Job_Title                    0
# Category                     0
# Refined_Seniority            0
# Remote                       0
# Job_Location                 0
# Salary_Range               199
# Salary_Period                0
# Average_Salary             199
# Job_Type                     0
# Posting_Date                 0
# Job_Summary                 17
# Primary_Skill               97
# Job_Description_Snippet    186
# Full_Job_Description         1
# dtype: int64

# %%
df['Primary_Skill'].unique()
# Out:
# array(['scientists', 'data', nan, 'Data', 'Scientists', 'Scientist'],
#       dtype=object)

# %%
df['Job_Summary'].unique()
# Out:
# array(['Work directly with project scientists in ICPAC Kenya, and collaborate where needed with scientists at ECMWF.',
#        "Working to build effective data products that drive real change in the business, you'll be involved at every step of the process, from exploratory data analysis…",
#        'Share your knowledge and enthusiasm for data science with colleagues; help them to be more data-savvy.',
#        'Experience using consumer behavioural data preferred.',
#        'The group has been working at the forefront of international thinking in how to bring machine learning to ultrasound, with recent interests in multi-modal…',
#        'Be recognised for your data wizardry and ability to tangibly talk about commercial discoveries.',
#        'The Cancer Care group in the School of Health Sciences (University of Surrey) is excited to be advertising for a Research Assistant / Research Fellow to work on…',
#        'To support development of rich data visualisation using industry tools.',
#        'The programme consists of a variety of development opportunities and the time to reflect and develop.',
#        'To be considered, you will hold a PhD (or equivalent) in a relevant scientific numerate subject, demonstrable experience, ability and practical success in…',
#        'Able to use data to identify equality and diversity issues;',
#        'You must have experience in data science and machine learning related subjects, such as data analysis, software development, data-driven control, cloud…',
#        'Knowledge of data visualisation tools, Tableau knowledge is a plus.',
#        'Writing code for the analysis of tool data, bridging the gap between raw data and customer interpretation.',
#        'Work with the Moorfield Reading Centre AI team to identify opportunities for clinical data analytics on the Moorfields Reading Centre cloud-based data hub.',
#        'SBU: School of Physics, Engineering and Computer Science.',
#        'Independent proficiency in the data science process including data cleansing, data validation, data modelling, model evaluation, visualization of insights.',
#        'Able to use data to identify equality and diversity issues.',
#        'Support the undertaking of complex data analytics studies.',
#        'Big data experience (Eg. Spark or equivalent).',
#        'The candidate will closely work with researchers from a diverse background including machine learning, systems and physics.',
#        'Areas of work include: data logistics; cloud computing; stewardship, archiving and data stack; science analysis platform; science support; training and outreach…',
#        'You will be responsible for building ML models, coding in Python, deploying and maintaining models and providing real time updates for the Trading team.',
#        'Delivering innovative, data driven solutions on large or complex data sets including gathering disparate data, extensive data manipulation, iteration of…',
#        'The Department of Pathology and the Department of Genetics are seeking to appoint a jointly held full-time Assistant Professor in Artificial Intelligence for…',
#        'The successful candidate will apply sophisticated machine learning methods to a wide variety of complex domains within natural language processing, large…',
#        'A passion for applying analytics and data science to solve business challenges.',
#        'The Professor in Artificial Intelligence and Machine Learning will contribute to and build programmes and modules to support the expansion of the School’s…',
#        'Global E-Commerce Data Science Department is a global full-stack data team who empowers and drives Global E-Commerce business growth through impactful data…',
#        nan,
#        'Become a Mimecaster and put corporate data under your protection.',
#        'Uncovering new Play through AI and Machine Learning - new play interactions, play patterns and immersive play experience!',
#        "You will be analysing player's behaviour using our first-party data collection tool and compare it with your own experience to make actionable recommendations.",
#        'We pair this expertise with machine learning, big data, and some of the most advanced technology available to predict movements in financial markets.',
#        'Good understanding of data science techniques like regression, statistical testing and machine learning methods to analyse data and time series.',
#        'You’ll be putting state-of-the-art deep learning technology into production use.',
#        'Collaborating with research group members and consortium members and contributing to the development and maintenance of the ELABORATOR data sharing platform.',
#        'You should also have demonstrable system development and programming skills to support big data analytics.',
#        'Experience of applying statistical and data science methods to real biological data in a research context.',
#        'Experience of using data science platforms and frameworks, for data tagging, model training and benchmarking.',
#        'Knowledge Transfer Partnerships (KTPs) are a unique UK-wide activity that help businesses to improve their competitiveness and productivity by making better use…',
#        'Developing and improving big data infrastructure and analytics within the team e.g. the spatial data science data model.',
#        'We are looking to appoint a Research Fellow with expertise in developing and applying probabilistic machine learning.',
#        'Able to have effective technical conversations with data engineers.',
#        'Driving best practices for data within Saint Gobain through use of new technologies, Machine Learning and AI.',
#        'To be able to demonstrate an awareness of the core data science skills; data wrangling, statistics & modelling, visualisation, technology and programming.',
#        'We are looking for creative problem-solvers and communicators with a passion for gaining insights from data and building tailored solutions to our client’s…',
#        'One+ year of experience with a data analysis and modelling language (Python, R or others).',
#        'Software development, including user experience (UX) design, data visualisation and dashboards.',
#        'You will be able to identify the best opportunities for named entity recognition, topic analysis and sentiment analysis on large volumes of social media data.',
#        "A knowledge of biologically relevant modern statistical data science approaches, including AI and 'big data' methods.",
#        'Mine data to supply business stakeholders with crucial insights that support decision making.',
#        'Understand and process GDPR requests so knowledge around data privacy is desirable.',
#        'Your job will involve discovering information hidden in vast amounts of data.',
#        'Our teams apply data science across the whole business – from solving customer problems like offer personalisation and online recommendation, to enterprise…',
#        'Data science skills, including handling of large data sets, modelling and evaluation.',
#        'Experience in a data science or related role.',
#        'This role is perfect for someone looking to work with business stakeholders to use data and data science techniques to help make better decisions for our…',
#        'Apply statistical knowledge to effectively model and analyse a variety of disparate data to make recommendations based on findings to improve operational,…',
#        'Master’s in data science with a background in Engineering.',
#        'Passion for data (both big and small) and data analytics.',
#        'The BGS Informatics Research Team are looking for a highly motivated and enthusiastic Data Scientist to join the data analytics and processing group.',
#        'You’ll be supporting the development of the cloud-based warehouse for Health Board linked data, including the data standards, security and quality and taking a…',
#        'In collaboration with Test Incorporated Limited, based in Harlow, Essex we have an exciting opportunity at the University of Aberdeen, with the School of…',
#        'Strong familiarity with data visualization and dimensionality reduction algorithms.',
#        'We are seeking an outstanding Research Associate to work on Speech Processing and Machine Learning for Detecting Cognitive Decline in the Speech and Hearing …',
#        'You’ll be working with scientists, data managers and expert web designers within our Water Resources science area and Freshwater Sustainability and Restoration…',
#        'The Department of Computer Science and Technology is an academic department that encompasses computer science along with many aspects of engineering, technology…',
#        'Some experience of delivering data-driven solutions; including gathering and manipulating disparate data, applying analytical techniques and visualising results…',
#        'You will be analysing data and consumer behaviours for their streaming services, app engagement and merchandise interaction.',
#        'Previous experience as a data scientist that demonstrates abilty to work with large datasets.',
#        'Experience of applying deep learning in frameworks like Tensorflow to real data and real problems would be an added advantage.',
#        'Ability to develop prototypes by manipulating and analysing complex, high-volume, high-dimensional data from varying sources;',
#        'Experience working with data preparation and data quality.',
#        'The project combines the use of advanced techniques from machine learning, data-driven modelling, and process system engineering.',
#        'Competent in using machine learning, mathematical modelling and visualisation tools for data analysis.',
#        'Multi-sensor data fusion and tracking.',
#        'For the entire set of literature documents you will develop QA capable methods to be deployed on the graph and underlying literature data to effectively…',
#        'Scientific understanding and practical experience with the state of the art in machine learning; knowledge of natural language understanding and foundation…',
#        'The Department of Computing and Mathematics is a large and successful academic community of students and staff in the Faculty of Science and Engineering that is…',
#        'Experience with using data visualisation tools such as PowerBI.',
#        'Improve and invent new approaches for molecular structure generation.',
#        'The main aim of this post is to develop a lung cancer risk prediction model using causality learning to identify causal structures from data including clinical,…',
#        'Present information using data visualisation techniques.',
#        'It encompasses data ethics and standards, learning & development, information management (asset control), data integration, end to end data management, data…',
#        'Previous experience working in an interdisciplinary environment with Biomedical or Life Sciences data and colleagues.',
#        'The Department of Computing and Mathematical Sciences offers a full range of contemporary, professionally accredited programmes incorporating Foundation Year,…',
#        'Use of descriptive data models for data aggregation to extract historical insights.',
#        'Have familiarity with genetics and the utilisation of data from genome-wide association studies.',
#        'Part of number data science projects/initiatives that form a roadmap exciting new data products and capabilities.',
#        'Innovate Collaboratively : Work hand-in-hand with data architects, engineers, digital, and data functions.',
#        'Demonstrated experience of using Python, R, or similar tools for data analysis, structuring, transforming and visualising big data.',
#        'Experience with development and application of data analytics for research data (data enrichment and semantic flows).',
#        'The range of topics is broad including agricultural food security, weather forecasting, climate modelling, seismic data processing and satellite imagery…',
#        'The suitable candidate will hold a PhD/DPhil (or near completion) or a graduate degree (e.g. MSc) with demonstrable post-qualification experience in data…',
#        'Data Scientists are part of a larger group of data people at GoCardless, with BI Analysts, BI Engineers, Data Engineers, Machine Learning engineers and data…',
#        'A long with making a real difference to our customers using our unrivalled data and industry leading data products.',
#        'Experience using earth-system observations for data assimilation.',
#        'The Data Science team partners with a variety of business divisions and delivers models that underpin data-driven decision-making within the Bank.',
#        'By combining artificial intelligence with an understanding of employee email behavior, Tessian is able to prevent complex email attacks and data loss incidents…',
#        'Key Dimensions: RESPONSIBILITIES: Key responsibilities include: -Management, development, and ongoing improvement of medical imaging information systems…',
#        'Must have a PhD ideally in Maths or Physics and an excellent understanding of data analytics.',
#        'Develop robust data pipelines to ensure efficient data collection, cleansing, transformation, and integration for analysis.',
#        'Highly proficient in SQL, and Python for data analysis and implementing data science models.',
#        '2+ years experience working as a data scientist / data analyst.',
#        'Collaborate with our data analysts to map data fields to hypotheses and curate, wrangle, and prepare data for use in their advanced analytical models.',
#        'Collaborate closely with data scientists, engineers and product managers to successfully integrate models into our commercial software.',
#        'Understand contributing data sources and implement robust transformation pipeline using DBT and Airflow.',
#        'This bank is offering a good opportunity for a data scientist to work on the on prem database to prepare for the azure implementation.',
#        'My leading banking client in London is looking for Data Scientist.',
#        'You’ll need to have a passion for analytics and statistics as you will often spend time analysing quantitative data while conducting economic research.',
#        'As a data scientist, you will need to:',
#        'Salary£60k - 90k per year + equity.',
#        'Have experience building Scalable microservices and data pipeline systems.',
#        'Experience of data quality challenges and practical approaches to address them.',
#        'Contribute to the development of data pipelines and ETL processes.',
#        'You will be working in key projects for leading organizations in data mining & knowledge Discovery, predictive modeling, trend modeling, Simulation models …',
#        'Experience and motivation to manage and support data scientists.',
#        'You will be required to develop solutions that ensure that the data and models required are readily available, accessible and meet the quality needed.',
#        'Line management experience within a data team.',
#        'Building of advanced data models to automate decision-making processes.',
#        'The researchers will be expected to carry out research with a high degree of independence at the intersection between computational neuroscience and machine…',
#        'Experience in business analytics building big data pipelines, schemas and data sets, within a media data context.',
#        'You will be located in the Department of Computer Science and, in addition to the new centre for Fundamental AI research, you will belong to a large community…',
#        'This is a post-doctoral research role to contribute to and develop the research work on the project “Tracking food quality at the bottom of marine food webs…',
#        'Each clinical study is set-up according to the clinical protocol which details the study design, objectives, dosing information, data collection and reporting…',
#        'All will be full-time permanent positions.',
#        'Kyseinen yritys tukee asiakkaitaan digitalisoitumisessa sekä dataliiketoiminnan rakentamisessa.',
#        'Applications are welcome from candidates working in any area of mathematics for environmental data science, including data assimilation and deep learning.',
#        'You will join a team of probabilistic modellers and machine learning researchers developing new collaborative AI principles and methods.',
#        'Knowledge of data warehousing and dimensional modelling.',
#        'Statistics and statistical data mining.',
#        'These models involve simulating the ocean climate using mathematical equations and physical models, and exploit complex input data arising from various sources,…',
#        'Manage and optimise processes for data ingestion, data cleansing & transformation, validation, data mining, data modelling and visualisation within the BI team…',
#        'The postholder will lead data science aspects of the project, designing automated tools to collect digital trace data from social media and other sources, glean…',
#        'Applying respondent level analytics to survey data.',
#        'One of the key KTP benefits for graduates is access to a training and travel budget over the 19 month project.',
#        'Network sensor systems for in-field imaging and data processing of crop pathogen activity (disease vectors).',
#        'Data Scientist/Machine Learning/Physics Modelling/Algorithm Development Engineer Scientists/Engineers will be designing, implementing, and testing algorithms,…',
#        'Report and present research findings and developments clearly and efficiently, to both other ML scientists and scientists of different disciplines.',
#        'Previous experience working in a team as a data scientist or optimisation specialist.',
#        'Processing large scale data from the data lakehouse.',
#        'In your first 3 months in the role you will work closely with the highly successful CTO of this business and head of data science to understand their backend…',
#        'You will work with all of the data science teams to define:',
#        'University qualification in computer science/data analytics.',
#        'Specifying data analytics and data science environments;',
#        '4+ years of experience as a data scientist (or 2+ years with a Ph.D. degree).',
#        'Proven experience in a relevant data science field.',
#        'Comfortable working on data platforms, such as Snowflake or Databricks, to manipulate data to engineer model features.',
#        'You will generate and analyse OMOP-mapped real world health data assets, adapt existing and develop new research methodologies and materials.',
#        'Develop and implement data science solutions using Python and Azure.',
#        'Part of a cross-disciplinary team, working closely with other data scientists, data engineers software engineers, data managers and business partners.',
#        'They are now looking for someone to set further data strategy with Greenfield opportunities across the organisation.',
#        'Initiate, develop, and maintain data pipelines and data models with outstanding craftsmanship.',
#        'Assist in development of new data driven methodologies.',
#        "Arm's Central Engineering Machine Learning Group is seeking highly motivated and creative Software Engineers to join a cross-site and multi-culture Machine…",
#        'Collaborate with cross-functional teams to define data requirements, identify data sources, and ensure data quality and integrity.',
#        'Assessing the impacts of data improvements on regulatory reporting, driving data improvement activities.',
#        'Extensive technical experience in delivering statistical analytics, data science and insight on large-scale data sets.',
#        'Partner with data engineering to build pipelines and sound data architecture for game projects.',
#        'As a data scientist, you will be responsible for utilising the most cutting edge data techniques to deliver bespoke solutions to both internal stakeholders and…',
#        "Three years' or more of experience in data science.",
#        'We leverage advanced statistical techniques and extensive data sets to develop innovative methodologies.',
#        'Demonstrable experience in cleansing and enriching of data, interpreting business requirements in terms of data architecture, database technology and data model…',
#        '8+ years of experience as a data scientist (or 6+ years with a relevant Ph.D. degree).',
#        'Feasibility assessment informed by theoretical assessment and laboratory experimentation.',
#        'Develop and support the internal ML pipeline.',
#        'This is an exciting opportunity to join a young technology company Reporting to the Head of Machine Learning, you will be a technology driven individual…',
#        'The research group is responsible for delivering novel and innovative solutions to ensure the future success of the company.',
#        'Previous experience working on marketing data-focused projects or a strong interest in applying data analysis skills to enhance marketing strategies.',
#        'Research on new technologies for improved data management and efficient retrieval.',
#        'Relevant experience (Post-Doctoral or industrial) in robotics, data fusion, tracking/estimation, pattern discovery & recognition, statistical inference,…',
#        'We work in cross-functional squads where every data scientist is a member of a central data discipline and fully embedded into 1 product squad alongside…',
#        'Experience in using techniques and developing machine learning/AI solutions, algorithm, data structure and data validation.',
#        'You will be responsible for data wrangling, data analysis, modeling, including model selection and producing quick applicable modeling solutions.',
#        'Carry out data quality checks on new data sets.',
#        'The Machine Learning Operations group at Oxford Nanopore Technologies is responsible for the engineering which enables training of ML models and their…',
#        'Applying and developing machine learning methods for the analysis of biological and genomic data.',
#        'The hybrid model provides the advantage of having both in-person time with colleagues and flexible at-home life optimizations.',
#        'Demonstrated experience applying data science to real-world data problems and translating findings into actionable insights.',
#        'Knowledge graphs and open linked data.',
#        'Ensure data accuracy and integrity through regular quality checks and data governance practices.',
#        'Proven business experience (1+ years) within a data scientist role, solving problems through data.',
#        'Build a data lake based on field data from multiple sources and aggregate these to support various functions within the business such as marketing, sales,…',
#        'Analysing large data sets, as well as undertaking data cleansing and validation projects.',
#        'You will be working with a team of fellow biomedical data scientists, data engineers and data curators as well as with a product development team to build…',
#        'Collaborate closely with data scientists, data engineers, architects, and the software development team.',
#        'Your models will support our bookmaking function, producing odds for sports events that see over £4bn turnover every year, and enable us to analyse and evaluate…',
#        'This is a brand-new role for a mathematically minded person to develop AI software (computer vision, data science, large language models, machine learning and…',
#        'Posted 5 days ago Flexible Contract GBP800 - GBP900 per day + Outside IR35.',
#        'The ideal candidate is expected to have research experience in natural language processing (NLP), deep learning and fairness in machine learning.',
#        'Depending on your assignment, it may be helpful to have expertise in one or more of the following areas: Bayesian statistics, causal inference, clinical trial…',
#        'You will have experience and understanding of data privacy.',
#        'As a Senior Data Scientist, you will be utilising your data science expertise to a variety of issues to support clients with the smooth running of their…',
#        'Conduct research about new data sources and unstructured data representation.',
#        'Applicants will be able to carry out digital RD&I using a range of data science skills including ML and/or visualisation and immersive data conversion and…',
#        'Collect and pre-aggregate data via Python.',
#        'Experience of teaching statistical and data science methods to biological scientists.',
#        'Collaborate as data expert within the business to understand and shape data projects.',
#        'Knowledge of programming languages such as C/C++, Python, Java or Perl.',
#        'Experience in data engineering, data modelling for advanced analytics, data processing on cloud, model management and app deployment on cloud is highly…',
#        'The successful Data Scientist will conduct data analysis and develop insights based on rich data sets.',
#        'Model using advanced statistical/ mathematical models, predict and segment data to hypothesize/ evolve uses cases to monetize data and generate other business…',
#        'Develop the computational strategy and lead a matrixed team of highly qualified computational scientists to deliver integrated predictive models using…',
#        'Apply data science techniques to interpret complex data sets and deliver insights to the business.',
#        'Understanding of data visualization tools such as Tableau or Power BI.',
#        'A proven interest in data science.',
#        'We will also consider exceptional candidates with a proven record of success in online data science competitions (e.g. Kaggle).',
#        'A3 Good knowledge of data engineering and data analysis.',
#        'Software solution sales in AI/ML, Deep Learning and Generative AI.',
#        'You will be expected to work across multiple projects and collaborate with various Intel teams such as customer-facing teams and architectural design teams.',
#        'Duties include evaluating and developing statistical evidence communication in contexts associated with government and public policy concerning AI and…',
#        'The post-holder will be expected to secure all necessary funding through SR processes, ensuring impact and value for money to the taxpayer Accountability &…',
#        'Machine Learning Scientist - Deep Tech.',
#        'Build reusable and innovative data modelling processes.',
#        'Strong programming skills and knowledge of algorithms and data structures.',
#        'Stay up-to-data on data availability.',
#        'A broad data background, across, data requirement elicitation, data visualisation, data engineering, advanced analytics, machine learning and data governance,…',
#        'Engage with other data scientists, software engineers, data engineers and network engineers to build compliant, efficient, and scalable solutions!',
#        'FMachine Learning Engineers/Computer Vision Scientists will have some of the following experience; Knowledge of Computer Science fundamentals such as object…',
#        'Python skills could be advantageous, particularly given the usage of various data tools, and the fact that AutoGPT is typically implemented in Python.',
#        'Managing a small team of data scientists supporting analytical product sales and innovation experiments.',
#        'The post will be within the Principles of Natural Language, Logic, and Statistics Research Lab of the UCL CS department.',
#        'The role is varied and the individuals could be working on analysing data daily across several data sets including electricity, gas, water, biomass and…',
#        'You will drive the changes in the core algorithm and infrastructure based on the findings of the engagement to make the platform easier to use and to scale…',
#        'In return we can offer a generous remuneration package, which includes relocation assistance where appropriate, the latest teaching facilities, and access to a…',
#        'Data ethics and privacy: Ensure compliance with ethical guidelines and data protection regulations throughout the research process, prioritizing data privacy…',
#        'Work closely with data scientists to solve difficult engineering and machine learning problems and produce high-quality code.',
#        'Der Einsatz ist in Vollzeit und zu 80% remote geplant.',
#        'Competitive salary and benefits package.',
#        'We are seeking an experienced data scientist to join our P&C insurance team.',
#        'Analyse data and build machine learning models for price optimisation purposes and forecasting demand.',
#        'Good knowledge of data structures, data modeling and software architecture.',
#        'Translate regulatory reporting requirements into highly accurate data models and set the strategy for how we ensure the best possible data accuracy.',
#        'Posted 6 days ago In-Office Permanent High Base+ Bonus.',
#        'Building on its existing research capacity and expertise, the School has identified a number of strategic themes that will form some of its key areas of…',
#        'Perform data processing and analysis, with reporting to customer teams and management,.',
#        'Selects from existing data sources and prepares data to be used by data science models.',
#        'Whilst not a requirement, prior experience working with panel or survey data would be considered an advantage.',
#        'You will have a PhD in computer science, geophysics, engineering, mathematics or a related discipline, good communication skills, and the ability to work as…',
#        'A competitive basic salary of £25-30k.',
#        'Bonus points for experience working with Open Banking data.',
#        '3-4 years hands-on data science/ machine learning experience.',
#        'Reporting to Dr Michael Suttie, the post holder will explore how the application of machine learning to 3D facial image analysis, neurocognitive performance…',
#        'Pangaea Data provides a novel AI driven product, which has clinically proven to characterize patients in a federated privacy preserving and scalable manner.',
#        'The post is supported by a PhD studentship (paying UK student fees and stipend for 3.5 years) and a generous startup package for equipment and travel.',
#        'Experience working with audio, radio frequency or imagery data.',
#        'The chosen candidate will play a vital role in utilising data and Data Science techniques to optimise solutions and operations, enabling data-driven decision…',
#        'Be a strong proponent for machine learning and data science across the business and contribute to the creation of a data science culture within the team.',
#        'This position requires a strong understanding and experience of the fashion and luxury goods industry, as well as a Data Analytics consulting background with…',
#        'ODR is split into three key business areas, Sales, Customer Success, and Talent.',
#        'Up to £200,000 per annum plus Equity.',
#        'You have previous experience of developing data and model governance procedures.',
#        'Experience of generating data science solutions by working with customer data to drive business activity is crucial.',
#        'You will be responsible for building data products to provide value to the business, all while advancing the company’s Machine Learning functionality.',
#        'Be the expert and go to person for data analysis, machine learning and data-led projects.',
#        'Direct and manage a team of data scientists, supporting their technical and personal development.',
#        'Responsibilities will include end-to-end delivery of data projects, from scoping the brief to stakeholder model presentation.',
#        'AI project management experience (project delivery, managing teams of data scientists).',
#        'We work in cross-functional squads where every data scientist is a member of a central data discipline and either embedded directly in a product squad or…',
#        'Familiarity with and interest in financial data required.',
#        'Understanding of data structures, data modeling and software architecture.',
#        'By blending design, product engineering, analytics, and automation, we build the custom-built software and data products of tomorrow.',
#        'Deep learning from molecular dynamics (MD) and optimal FDDFT model for non-equilibrium: use MD data and deep neural networks to machine learn the terms, which…',
#        'This is a pure research role that would suit those who enjoy finding relationships in large data sets and working out how to interpret these results.',
#        'Experience of managing data scientists and leading ML projects into production.',
#        "As part of your job you'll work closely with product managers, data scientists, backend engineers, designers and researchers in an agile product environment.",
#        'Worked with very large data sets before (billions of records).',
#        'Research Led, Start Up focusing on behavioural learning and simulation in virtual environments is looking to recruit a Machine Learning Researcher.',
#        'Solid understanding of data manipulation, data visualization, and data cleaning techniques.',
#        'Provide people management and developmental support to other ML research scientists.',
#        '3+ years of commercial experience in a data science position.',
#        'Solid understanding of ML algorithms, data pre-processing, feature selection, and model evaluation techniques.',
#        'Processing large scale data from their data lakehouse.',
#        'Skills with RDBMS (Postgres, MySQL or similar) and document based (NoSQL) data stores (MongoDB or similar).',
#        'The chosen candidate(s) will work with a diverse and highly interdisciplinary team of scientists, engineers, and cross-functional partners, and will have access…',
#        'This role offers the chance to work with vast and complex data sets, applying data-mining, graph analysis and machine learning techniques for a variety of…',
#        'Understand the principles of computer science algorithms and data structures.',
#        'Expertise in protocol interpretation, data collection and data cleaning specification development.',
#        'Highly advantageous to have used Python or R as well as cloud computing platforms and big data tools.',
#        'Productionize machine learning, statistical, and optimization model-based features developed by applied and data scientists.',
#        'Ability to process large data sets accurately.',
#        'Strong knowledge of querying and manipulating data using SQL, R or Python.',
#        'Working on various parts of the data science lifecycle.',
#        'This role will be working within a Financial Services client so any previous FS experience would be highly desirable.',
#        'Evaluate data sources and collection methods to enhance data quality and efficiency.',
#        'As well as experience of using a variety of data mining/data cleansing/data analysis methods, using a variety of data tools, building and implementing models,…',
#        'Contributing to data architecture and data design.',
#        'The role would also see you work to create new or refine existing data processing pipelines for large amounts of data.',
#        'Ability to competently converse with life scientists to inform model development and testing.',
#        'Their task, to disrupt the insurance space – taking the business towards a new future as a true data organisation.',
#        'Have knowledge and experience of using data science techniques is essential, e.g. data cleaning and processing, visualisation, statistical analysis.',
#        'You will be involved in the data-mining, machine learning and graph analysis techniques for a variety of modelling problems involving customers, their…',
#        'Provide analytic support in the market and interfacing with country commercial teams to provide data driven guidance.',
#        'Software engineering and / or data engineering skills for prototyping.',
#        'Gather and pre-process data for model training and validation.',
#        'Devise better data-driven models of human behavior.',
#        'You could pioneer the AI space in a well-funded exhilarating start-up based in London!',
#        'As a Data Analyst Consultant, you will play a key role on multiple accounts, working across statistical analysis, econometrics and insight.',
#        'Collaborate with data scientists and product implementation engineers during NetReveal Sensa deployments.',
#        'Productise, develop, optimise and deploy NLP algorithms, supportive modules (such as architects, data processors, APIs) and other features in Pangaea’s product.',
#        'Technology Leader is looking for a well qualified software C++ engineer/scientist or Graduate Computer Vision Scientist/Software Engineer C++ to join its team…',
#        'Posted 6 days ago Hybrid Permanent $Base + Sign On.',
#        'Tackle massive datasets and navigate data pipelines like a seasoned explorer.',
#        "You'll work on breaking down and analysing retail customer data using pricing optimisation modelling.",
#        'A passion for all things data science, eager to stay on top of the latest advancements.',
#        'Solve real world problems within our business that span various data science domains such as Price Optimization, Reinforcement Learning, NLP, Computer Vision,…',
#        'Use SQL to extract and wrangle data.',
#        'Perform hands-on data analyses and modelling with very large data sets.',
#        'It is desirable, but not essential, that they also have experience with longitudinal methods and clinical data.',
#        'Brilliant design, documentation and presentation skills including data visualisation (Qlik preferred).',
#        'Working with trading teams to identify potential prediction targets and relevant data sets.',
#        'Our computer vision/machine learning team is responsible for developing solutions that allow us to scale our automatic understanding from raw video data.',
#        'You are comfortable with designing and implementing data pipelines using batch data transfers.',
#        'Use machine learning approaches to glean insightful information from high-dimensional biological data, such as DNA sequencing, gene expression, and proteomics…',
#        'Solid understanding of computer science fundamentals, including data structures, algorithms, data modelling and software architecture.',
#        'As a senior data scientist, you are also expected to train and mentor junior data scientist and data science apprentices as well as to lead data science…',
#        'Experience using mass sets of customer data (and ideally credit bureau or payments data) to solve problems.',
#        'Implement scalable data architecture, storage and data warehousing to maintain high availability and data integrity.',
#        'Demonstrable experience developing capabilities analysing large amounts of data to identify patterns / trends and building useable and value-added data products…',
#        'Experience working with biomedical data.',
#        'Eka Finance London, United Kingdom.',
#        'Understanding of data structures, data modelling and software architecture.',
#        'Proven experience in data analytics, data science, or business intelligence.',
#        'At Roku, we are a company of data-focused builders, particularly on the data-driven team.',
#        'You are skilled on the analysis of neural data.',
#        'Substantial experience designing and delivering data science solutions in a complex commercial environment.',
#        'Strong data modelling and data architecture skills.',
#        'The principal data scientist should be experienced in using statistical, algorithmic, mining and/or visualisation techniques to address complex business…',
#        'The AI team at Samsung Research UK is looking for exceptional engineers to join the growing team in Staines-upon-Thames.',
#        'Can work with large scale computing frameworks, data analysis systems and modeling environments.',
#        'Applying statistical and machine learning techniques to historical data, predictive signals, and trading strategies.',
#        'SALARY UP TO £45,000.',
#        'Help develop and retain a data team of 20 top tier data analysts, data scientists, data managers and machine learning engineers.',
#        'We are looking for someone who is inquisitive, excels in solving complex data-centric problems, ready to explore and visualise data and bring their experience…',
#        'Applying a range of data science techniques to analyse data, insights and solve problems in a real-world setting (e.g., machine learning, network analysis, data…',
#        'Senior Data Scientist - 1x/month in London - up to GBP80k.',
#        'Integral to the movement of data.',
#        'Highly experienced in handling and manipulating big data from multiple sources, with proven programming skills;',
#        'Experience leading end-to-end data science projects.',
#        'Develop and apply high quality data analytics to drive insights that inform model development.',
#        'Familiarity with data visualization and dimensionality reduction algorithms.',
#        'AWS Dynamo / No-SQL (Document-based data Json data).',
#        'They currently have no BI or data function in the business, and are looking for you to help the business with how they use data to improve sales and revenue…',
#        'Developing data science solutions to big data and cyber security problems.',
#        'Translate data into actionable insights and recommendations to optimize marketing strategies.',
#        'We are seeking a “lead data scientist” with exceptional planning, stakeholder management, domain knowledge and implementation track record to help us make data…',
#        'Act as a subject matter expert in data science and machine learning and coach other data scientists.',
#        'Support the build and deployment of data systems and their data pipelines whilst being able to analyse and resolve data quality issues.',
#        'Proficiency in programming languages such as Python, R, or Java for data manipulation and analysis.',
#        'Three+ years of experience with a data analysis and modelling language (Python, R or others).',
#        'Collaborate with data scientists and engineers to develop, train, and deploy AI models and systems.',
#        'At least 2 years of commercial data science experience (preferably using Python).',
#        'Experienced and knowledgeable in some aspects of the engineering of data processing.',
#        'Develop and deploy production-quality machine learning frameworks for on-device and backend inference.'],
#       dtype=object)

# %%
data = df.copy()

# %% [markdown]
# Skill Extract from the JOB DESCRIPTION

# %%
# List of data science-related skills and techniques
skills_list = [
    "Python", "R", "SQL", "Machine Learning", "Deep Learning", "Neural Networks", "TensorFlow", "Keras", "PyTorch",
    "NLP", "Big Data", "Hadoop", "Spark", "Tableau", "PowerBI", "Excel", "SAS", "MATLAB", "Java", "Scala",
    "Data Visualization", "Data Cleaning", "Data Engineering", "Data Analysis", "Statistics", "Time Series", "Clustering",
    "Regression", "Decision Trees", "Random Forest", "SVM", "API", "Cloud", "AWS", "Azure", "GCP", "Docker", "Kubernetes"
]

def regex_extract_skills(text):
    """Extract skills from the text using regular expressions."""
    """Refined regex-based skill extraction to accurately detect 'R'."""
    mentioned_skills = []
    
    for skill in skills_list:
        # Special handling for "R"
        if skill == "R":
            r_patterns = [
                r'\sR\s',  # Standalone 'R' not followed by a period and alphanumeric character
                r'Python/R',  # 'Python/R'
                r'R/Python',   # 'R/Python'
                r'R-Studio'    # 'R-Studio'
            ]
            if any(re.search(pattern, text, re.IGNORECASE) for pattern in r_patterns):
                mentioned_skills.append(skill)
        else:
            pattern = r'\b' + re.escape(skill.lower()) + r'\b'
            if re.search(pattern, text.lower()):
                mentioned_skills.append(skill)
    
    return ', '.join(mentioned_skills)

# %%
# Test the refined skill extraction on the Full_Job_Description column
# data['Regex_Skills_From_Full_Description'] = data['Full_Job_Description'].apply(lambda x: regex_extract_skills(str(x)))
df['Regex_Skills_From_Full_Description'] = df['Full_Job_Description'].apply(lambda x: regex_extract_skills(str(x)))

# %%
def count_skills_frequency(skill_column):
    """Count the frequency of each skill in the given pandas Series and return the sorted list."""
    # Initialize a Counter object
    skills_counter = Counter()
    
    # Update the counter for each set of skills
    for skill_set in skill_column:
        skills_counter.update(skill_set.split(', '))
    
    # Sort the skills by frequency
    sorted_skills = sorted(skills_counter.items(), key=lambda x: x[1], reverse=True)
    
    return sorted_skills

# %%
count_skill = count_skills_frequency(df['Regex_Skills_From_Full_Description'])

# %%
count_skill
# Out:
# [('Python', 262),
#  ('Machine Learning', 258),
#  ('Statistics', 121),
#  ('SQL', 120),
#  ('Cloud', 94),
#  ('Deep Learning', 76),
#  ('Data Analysis', 68),
#  ('R', 60),
#  ('TensorFlow', 59),
#  ('NLP', 56),
#  ('PyTorch', 54),
#  ('Big Data', 53),
#  ('AWS', 51),
#  ('Azure', 43),
#  ('Java', 40),
#  ('Spark', 34),
#  ('Neural Networks', 29),
#  ('Tableau', 28),
#  ('Data Engineering', 28),
#  ('Hadoop', 26),
#  ('Regression', 25),
#  ('', 24),
#  ('Keras', 22),
#  ('Time Series', 21),
#  ('MATLAB', 21),
#  ('GCP', 20),
#  ('Docker', 18),
#  ('Excel', 18),
#  ('SAS', 16),
#  ('Clustering', 16),
#  ('Kubernetes', 15),
#  ('Data Visualization', 13),
#  ('API', 11),
#  ('Scala', 9),
#  ('PowerBI', 7),
#  ('Decision Trees', 4),
#  ('Data Cleaning', 4),
#  ('Random Forest', 3),
#  ('SVM', 2)]

# %% [markdown]
# To check if the 'R' capture correctly

# %%
def extract_specific_r_context(text):
    """Extract a snippet of text around the specific detected 'R' patterns for context."""
    r_patterns = [
        r'.{0,20}\sR\s.{0,20}',  # Standalone 'R' not followed by a period and alphanumeric character
        r'.{0,20}Python/R.{0,20}',  # 'Python/R'
        r'.{0,20}R/Python.{0,20}',    # 'R or' (e.g., R or SAS)
        r'.{0,20}R-studio.{0,20}'
    ]
    
    # Find all matches for the R patterns
    matches = []
    for pattern in r_patterns:
        matches.extend(re.findall(pattern, text, re.IGNORECASE))
    
    # Join multiple matches (if any) with ' ... ' for clarity
    return ' ... '.join(matches)

# %%
data = df.copy()

# %%
# Extract the specific context in which "R" appears from the Full_Job_Description column based on the refined regex extraction method
r_context_entries_refined = data[data['Regex_Skills_From_Full_Description'].str.contains('R', na=False, case=False)]
r_context_from_refined_extraction = r_context_entries_refined['Full_Job_Description'].apply(lambda x: extract_specific_r_context(str(x)))

# %%
# Display the extracted specific context based on the refined regex extraction method
data['R_context'] = r_context_from_refined_extraction
data[data['Regex_Skills_From_Full_Description'].str.contains(r'\bR\b', na=False, case=True, regex=True)].head()
# Out:
#                                               Job_URL  \
# 3   https://uk.indeed.com/rc/clk?jk=8bd213b8a32179...
# 7   https://uk.indeed.com/rc/clk?jk=671c27caa3bb60...
# 12  https://uk.indeed.com/rc/clk?jk=72d8aa70c30b88...
# 17  https://uk.indeed.com/rc/clk?jk=8960cabd3742fd...
# 19  https://uk.indeed.com/rc/clk?jk=89807539723295...
#
#                    Company_Name                                Job_Title  \
# 3                        Disney                           Data Scientist
# 7   Devon Partnership NHS Trust                           Data Scientist
# 12                         LEGO  Data Scientist, Marketing Effectiveness
# 17                         JATO                           Data Scientist
# 19                    ERM Group    Graduate Data Scientist (Entry Level)
#
#         Category Refined_Seniority      Remote Job_Location    Salary_Range  \
# 3   Data Science         Mid-Level  Not remote       London            None
# 7   Data Science         Mid-Level  Not remote       Exeter  [43742, 50056]
# 12  Data Science         Mid-Level      Hybrid       London            None
# 17  Data Science         Mid-Level      Remote       Remote            None
# 19  Data Science       Entry-level  Not remote     Aberdeen            None
#
#     Salary_Period  Average_Salary       Job_Type  Posting_Date  \
# 3   Not specified             NaN  Not specified             4
# 7            Year         46899.0      Permanent             2
# 12  Not specified             NaN  Not specified            30
# 17  Not specified             NaN      Full-time            18
# 19  Not specified             NaN      Full-time             6
#
#                                           Job_Summary Primary_Skill  \
# 3   Experience using consumer behavioural data pre...          data
# 7   To support development of rich data visualisat...          data
# 12  Knowledge of data visualisation tools, Tableau...          data
# 17  Independent proficiency in the data science pr...          data
# 19  Support the undertaking of complex data analyt...          data
#
#                               Job_Description_Snippet  \
# 3   Experience developing and scaling data science...
# 7   The post holder will pro-actively identify opp...
# 12  Cleaning and interrogating large data sets to ...
# 17                                                NaN
# 19  Have a proven ability in big data analysis and...
#
#                                  Full_Job_Description  \
# 3   \n \n  Data Scientist \n  \n  Apply Later \n  ...
# 7   Job details\nHere’s how the job details align ...
# 12  \n \n  \n   \n    Location\n   \n   \n     Lon...
# 17  Job detailsHere’s how the job details align wi...
# 19  Job detailsHere’s how the job details align wi...
#
#                    Regex_Skills_From_Full_Description  \
# 3                          Python, R, SQL, Statistics
# 7                                           Python, R
# 12  Python, R, SQL, Big Data, Hadoop, Tableau, Sta...
# 17  Python, R, Machine Learning, NLP, Data Enginee...
# 19  Python, R, Machine Learning, Big Data, Data An...
#
#                                       R_context
# 3   xperience in Python, R or another statistic
# 7   g techniques such as R & Python. The post h
# 12  /HQL (Hadoop, Hive), R or Python. It will b
# 17                  Proficiency using Python/R
# 19  ent in Python and/or R (other programming l

# %% [markdown]
# ### Plot the job opening by location

# %%
df['Job_Location'].unique()
# Out:
# array(['Oxford', 'London', 'Remote', 'Guildford', 'Exeter', 'Birmingham',
#        'Lincoln', 'Didcot', 'Hatfield', 'Aberdeen', 'Cambridge',
#        'Manchester', 'Bristol', 'Edinburgh', 'Glasgow', 'Leicester',
#        'England', 'Sheffield', 'Harpenden', 'Newcastle upon Tyne',
#        'Leicestershire', 'West Midlands', 'Letchworth', 'Norwich',
#        'Wigan', 'Nottingham', 'Newbridge', 'Leeds', 'Dundee',
#        'Hammersmith', 'Charlbury', 'Sidcup', 'High Wycombe',
#        'Wolverhampton', 'Thame', 'Warrington', 'Reading', 'Plymouth',
#        'Belfast', 'Warwick', 'Hullavington', 'East of England', 'Gaydon',
#        'United Kingdom', 'Bollington', 'Southampton', 'Birkenhead',
#        'West London', 'South West', 'Epsom', 'Bath', 'Stevenage',
#        'Redhill', 'Oxfordshire', 'Cambridgeshire', 'Brentwood',
#        'Guernsey', 'Lancashire', 'Cornwall', 'Osterley', 'Colchester',
#        'Dunstable', 'Winnersh', 'Swindon', 'Haywards Heath', 'Wales',
#        'Perth', 'St Albans', 'Headington', 'Coventry', 'Bradford',
#        'Abingdon', 'Chelmsford', 'Brighton and Hove', 'Holborn',
#        'Sunderland', 'Redditch', 'Hook', 'South Kensington', 'Boston',
#        'Bracknell', 'Greater London', 'Tadworth', 'Slough',
#        'Milton Keynes', 'Staines-upon-Thames', 'Lowestoft', 'Derby',
#        'Kingston upon Hull', 'Malvern'], dtype=object)

# %%
locations = df['Job_Location'].value_counts()
locations_df = pd.DataFrame(locations)
locations_df.index.name = 'city'
locations_df.head()
# Out:
#             Job_Location
# city
# London               169
# Cambridge             15
# Remote                14
# Manchester            14
# Bristol               11

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="myapp")

coords = {loc: geolocator.geocode(loc) for loc in locations.index}
coords = {loc: (c.latitude, c.longitude) for loc, c in coords.items() if c}

# %%
coords
# Out:
# {'London': (51.5073359, -0.12765),
#  'Cambridge': (52.2055314, 0.1186637),
#  'Remote': (43.0059455, -123.8925908),
#  'Manchester': (53.4794892, -2.2451148),
#  'Bristol': (51.4538022, -2.5972985),
#  'Oxford': (51.7520131, -1.2578499),
#  'Birmingham': (52.4796992, -1.9026911),
#  'Leeds': (53.7974185, -1.5437941),
#  'Edinburgh': (55.9533456, -3.1883749),
#  'Reading': (51.4564242, -0.9700664),
#  'England': (52.5310214, -1.2649062),
#  'Glasgow': (55.861155, -4.2501687),
#  'Harpenden': (51.8145103, -0.3549311),
#  'Sheffield': (53.3806626, -1.4702278),
#  'Leicester': (52.6362, -1.1331969),
#  'Nottingham': (52.9534193, -1.1496461),
#  'Aberdeen': (57.1482429, -2.0928095),
#  'Guildford': (51.2356068, -0.5732063),
#  'West London': (38.1943567, -81.3686944),
#  'Lincoln': (40.8088861, -96.7077751),
#  'Belfast': (54.596391, -5.9301829),
#  'United Kingdom': (54.7023545, -3.2765753),
#  'High Wycombe': (51.627422, -0.7484153),
#  'South West': (5.3356587, 100.2389496),
#  'Warwick': (52.2814519, -1.5815742),
#  'Newcastle upon Tyne': (54.9738474, -1.6131572),
#  'Dunstable': (51.8861316, -0.5209341),
#  'Didcot': (51.6056908, -1.2467923),
#  'Exeter': (50.7255794, -3.5269497),
#  'Perth': (-31.9558933, 115.8605855),
#  'St Albans': (51.753051, -0.3379675),
#  'Wales': (52.2928116, -3.73893),
#  'Headington': (51.7601978, -1.2109908),
#  'Haywards Heath': (50.9999616, -0.1049747),
#  'Swindon': (51.5613683, -1.7856853),
#  'Coventry': (52.4081812, -1.510477),
#  'Chelmsford': (51.7345329, 0.4730532),
#  'Bradford': (53.7944229, -1.7519186),
#  'Abingdon': (51.6714842, -1.2779715),
#  'Winnersh': (51.430882, -0.8778641),
#  'Bracknell': (51.4143513, -0.7449925),
#  'Brighton and Hove': (50.8453169, -0.14974689789029522),
#  'Tadworth': (51.2912247, -0.2326709),
#  'Kingston upon Hull': (53.76238625, -0.3301213755327681),
#  'Derby': (52.9212617, -1.4761491),
#  'Lowestoft': (52.4766308, 1.7537638),
#  'Staines-upon-Thames': (51.434012, -0.511044),
#  'Milton Keynes': (52.0406502, -0.7594092),
#  'Slough': (51.5111014, -0.5940682),
#  'Greater London': (51.4893335, -0.14405508452768728),
#  'Holborn': (51.5195982, -0.1137266),
#  'Osterley': (51.4832218, -0.3517985),
#  'Boston': (42.3554334, -71.060511),
#  'South Kensington': (51.4955817, -0.1831368),
#  'Hook': (51.286321099999995, -0.9517457693027948),
#  'Redditch': (52.3057655, -1.9417444),
#  'Sunderland': (54.9058512, -1.3828727),
#  'Colchester': (51.8896903, 0.8994651),
#  'Southampton': (50.9025349, -1.404189),
#  'Cornwall': (50.416667, -4.75),
#  'Warrington': (53.4018582, -2.5680223597163048),
#  'Hatfield': (51.7634675, -0.2258741),
#  'Leicestershire': (52.666667, -1.0),
#  'West Midlands': (52.5050033, -1.964396123331272),
#  'Letchworth': (51.9767243, -0.2305199),
#  'Norwich': (52.6285576, 1.2923954),
#  'Wigan': (53.5457188, -2.6264624),
#  'Newbridge': (55.9391687, -3.4079986),
#  'Dundee': (56.4605938, -2.97019),
#  'Hammersmith': (51.4920377, -0.2236401),
#  'Charlbury': (51.874697499999996, -1.4806611669892824),
#  'Sidcup': (51.4264002, 0.101044),
#  'Wolverhampton': (52.5847651, -2.127567),
#  'Thame': (51.7482733, -0.9781805),
#  'Plymouth': (50.3712659, -4.1425658),
#  'Lancashire': (53.8611703, -2.5650887919475496),
#  'Hullavington': (51.5372741, -2.1528703),
#  'East of England': (52.2199774, 0.4875777469166293),
#  'Gaydon': (52.183882249999996, -1.4665136858172174),
#  'Bollington': (53.29348, -2.1107855),
#  'Birkenhead': (53.3895177, -3.0248007),
#  'Epsom': (51.3326098, -0.2678212),
#  'Bath': (51.3813864, -2.3596963),
#  'Stevenage': (51.9016663, -0.2027155),
#  'Redhill': (51.2404691, -0.1682816),
#  'Oxfordshire': (51.833333, -1.25),
#  'Cambridgeshire': (52.333333, 0.083333),
#  'Brentwood': (37.9317766, -121.696026),
#  'Guernsey': (49.4566233, -2.5822348),
#  'Malvern': (52.1159559, -2.3258985)}

# %%
# Convert the dictionary to a DataFrame
lat_lng_df = pd.DataFrame.from_dict(coords, orient='index', columns=['Latitude', 'Longitude'])
# Rename the index to 'City'
lat_lng_df.index.name = 'city'
lat_lng_df.rename({'Latitude': 'lat', 'Longitude': 'lng'}, axis='columns', inplace=True)

# %%
lat_lng_df.head()
# Out:
#                   lat         lng
# city
# London      51.507336   -0.127650
# Cambridge   52.205531    0.118664
# Remote      43.005946 -123.892591
# Manchester  53.479489   -2.245115
# Bristol     51.453802   -2.597298

# %%
open_job = pd.merge(locations_df, lat_lng_df, on="city")
open_job.reset_index(inplace=True)
open_job.head()
# Out:
#          city  Job_Location        lat         lng
# 0      London           169  51.507336   -0.127650
# 1   Cambridge            15  52.205531    0.118664
# 2      Remote            14  43.005946 -123.892591
# 3  Manchester            14  53.479489   -2.245115
# 4     Bristol            11  51.453802   -2.597298

# %%
# Plotting the Geographical Distribution of Job Openings in the UK
top_10_cities = open_job.nlargest(10, 'Job_Location')
top_10_cities
# Out:
#          city  Job_Location        lat         lng
# 0      London           169  51.507336   -0.127650
# 1   Cambridge            15  52.205531    0.118664
# 2      Remote            14  43.005946 -123.892591
# 3  Manchester            14  53.479489   -2.245115
# 4     Bristol            11  51.453802   -2.597298
# 5      Oxford            10  51.752013   -1.257850
# 6  Birmingham            10  52.479699   -1.902691
# 7       Leeds             9  53.797418   -1.543794
# 8   Edinburgh             9  55.953346   -3.188375
# 9     Reading             8  51.456424   -0.970066

# %%
import folium

# Create a map centered around coordinates
m = folium.Map(location=[53.483959, -1.244644], zoom_start=6)

# Add points to the map
for i, row in open_job.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['lng']],
        radius=row['Job_Location'] / 10,  # Adjust the scaling factor as needed
        color='blue',
        fill=True,
        fill_color='blue',
        tooltip=row['city']  # Tooltip to show on hover
    ).add_to(m)

# Annotate top 10 cities
top_10_cities = open_job.nlargest(10, 'Job_Location')
for i, row in top_10_cities.iterrows():
    folium.Marker(
        location=[row['lat'], row['lng']],
        tooltip=row['city']
    ).add_to(m)

m.save('map_with_tooltip.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7e8ce464cbe070f7d75ff2844e08bad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7e8ce464cbe070f7d75ff2844e08bad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7e8ce464cbe070f7d75ff2844e08bad = L.map(
#                 &quot;map_f7e8ce464cbe070f7d75ff2844e08bad&quot;,
#                 {
#                     center: [53.483959, -1.244644],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ed48ab3ca90b3696174d5dd3c17143c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f7e8ce464cbe070f7d75ff2844e08bad);
#
#
#             var circle_marker_50c7bc280d9b0c859466e8f93311d505 = L.circleMarker(
#                 [51.5073359, -0.12765],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 16.9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f7e8ce464cbe070f7d75ff2844e08bad);
#
#
#             circle_marker_50c7bc280d9b0c859466e8f93311d505.bindTooltip(
#                 `&lt;div&gt;
#                      London
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_2dafffba05241451fd12b2b47346c112 = L.circleMarker(
#                 [52.2055314, 0.1186637],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f7e8ce464cbe070f7d75ff2844e08bad);
#
#
#             circle_marker_2dafffba05241451fd12b2b47346c112.bindTooltip(
#                 `&lt;div&gt;
#                      Cambridge
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f5b84affe4ba791e288331ed520545ee = L.circleMarker(
#                 [43.0059455, -123.8925908],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f7e8ce464cbe070f7d75ff2844e08bad);
#
#
#             circle_marker_f5b84affe4ba791e288331ed520545ee.bindTooltip(
#                 `&lt;div&gt;
#                      Remote
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_a5728a12f8401d57c5a00ac7cd1c32e6 = L.circleMarker(
#                 [53.4794892, -2.2451148],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f7e8ce464cbe070f7d75ff2844e08bad);
#
#
#             circle_marker_a5728a12f8401d57c5a00ac7cd1c32e6.bindTooltip(
#                 `&lt;div&gt;
#                      Manchester
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_da88b5d016e0716913af7dc3b1cf64e6 = L.circleMarker(
#                 [51.4538022, -2.5972985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &qu
